# %% [markdown]
# #### price threshold 변경 (수수료 생각해서 손해보지 않을만큼 상승을 기준으로 파악)
# #### 다시 삼진분류
# #### Focal_loss
# #### num_head 8
# #### ff_dim 128

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow.keras.backend as K

# %%
# 데이터 로드
data = pd.read_csv('./000660.csv')

# 데이터 칼럼명 변경
data = data.rename(
    columns={
        '시가': 'Open',
        '고가': 'High',
        '저가': 'Low',
        '종가': 'Close',
        '거래량': 'Total_Volume',
        '매도량': 'Sell_Volume',
        '매수량': 'Buy_Volume'
    })

# %%
# 결측치 제거
data = data.dropna()

# %%
# 특성 선택
price_features = ['Open', 'High', 'Low', 'Close']
volume_features = ['Buy_Volume', 'Sell_Volume', 'Total_Volume']
features = price_features + volume_features

# %%
# 거래량 강도 계산
data['Volume_Intensity'] = data['Buy_Volume'] - data['Sell_Volume']
data['Volume_Intensity_Ratio'] = data['Volume_Intensity'] / (data['Total_Volume'] + 1e-5)
data['Buy_Sell_Ratio'] = data['Buy_Volume'] / (data['Sell_Volume'] + 1e-5)

# %%
# 새로운 특성들을 특성 리스트에 추가
features.extend(['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio'])

# %%
# 이동 평균선 추가
data['MA_5'] = data['Close'].rolling(window=5).mean()
data['MA_20'] = data['Close'].rolling(window=20).mean()
data['MA_60'] = data['Close'].rolling(window=60).mean()
data['MA_5_20_Diff'] = data['MA_5'] - data['MA_20']
data['MA_20_60_Diff'] = data['MA_20'] - data['MA_60']

# %%
# 추가된 특성을 특성 리스트에 포함
features.extend(['MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff'])

# %%
# 이동 평균선 계산 후 결측치 제거
data = data.dropna()

# %%
# 가격 급변 레이블링
price_threshold = 0.0021  # 0.5% 이상 변동 시 급변으로 간주

data['Price_Change'] = data['Close'].pct_change()
data = data.dropna()

def label_price_change(change):
    if change >= price_threshold:
        return 2  # 상승
    elif change <= -price_threshold:
        return 0  # 하락
    else:
        return 1  # 보합

data['Price_Label'] = data['Price_Change'].apply(label_price_change)

# %%
# 결측치 제거 (최종)
data = data.dropna()

# %%
# 스케일러 딕셔너리 생성
scalers = {}

# %%
# 가격 관련 특성 스케일링
for feature in price_features + ['MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff']:
    scaler = StandardScaler()
    data[feature] = scaler.fit_transform(data[[feature]])
    scalers[feature] = scaler

# %%
# 거래량 관련 특성 스케일링
for feature in volume_features + ['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio']:
    scaler = RobustScaler()
    data[feature] = scaler.fit_transform(data[[feature]])
    scalers[feature] = scaler

# %%
# 시퀀스 생성 함수 정의
def create_sequences(data, sequence_length, expect, target):
    X = []
    y = []
    data_values = data[features].values
    labels = data[target].values
    for i in range(len(data_values) - sequence_length - expect + 1):
        X.append(data_values[i:i+sequence_length])
        y.append(labels[i+sequence_length + expect - 1])
    return np.array(X), np.array(y)

# %%
# 데이터 생성
sequence_length = 60  # 시퀀스 길이
expect = 10
X, y = create_sequences(data, sequence_length, expect, target='Price_Label')

# %%
# 시간 순서대로 데이터 분할
train_size = int(len(X) * 0.7)
val_size = int(len(X) * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size+val_size]
y_val = y[train_size:train_size+val_size]

X_test = X[train_size+val_size:]
y_test = y[train_size+val_size:]

# %%
# 클래스 분포 확인
unique, counts = np.unique(y_train, return_counts=True)
print("클래스 분포:", dict(zip(unique, counts)))
# Out:
# 클래스 분포: {0: 4365, 1: 121668, 2: 4581}

# %%
# 하이퍼 파라미터 설정
d_model = X_train.shape[2]
num_heads = 4
ff_dim = 64
num_layers = 2
dropout_rate = 0.1
num_classes = 3  # 레이블 클래스 수

# %%
# 포지셔널 인코딩 정의
class PositionalEncoding(layers.Layer):
    def __init__(self, sequence_length, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(sequence_length, d_model)
    
    def get_config(self):
        config = super().get_config().copy()
        return config
    
    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            np.arange(position)[:, np.newaxis],
            np.arange(d_model)[np.newaxis, :],
            d_model)
        
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)
    
    def get_angles(self, pos, i, d_model):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
        return pos * angle_rates
    
    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
# 트랜스포머 블록 정의
def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(inputs, inputs)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)
    
    # Feed Forward Network
    ffn_output = layers.Dense(ff_dim, activation='gelu', kernel_regularizer=regularizers.l2(1e-4))(out1)
    ffn_output = layers.Dense(head_size)(ffn_output)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

# %%
# 모델 정의
def create_model():
    inputs = layers.Input(shape=(sequence_length, d_model))
    x = PositionalEncoding(sequence_length, d_model)(inputs)
    
    for _ in range(num_layers):
        x = transformer_block(x, d_model, num_heads, ff_dim, dropout_rate)
    
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 60, 15)]     0           []
#
#  positional_encoding (Positiona  (None, 60, 15)      0           ['input_1[0][0]']
#  lEncoding)
#
#  multi_head_attention (MultiHea  (None, 60, 15)      3795        ['positional_encoding[0][0]',
#  dAttention)                                                      'positional_encoding[0][0]']
#
#  dropout (Dropout)              (None, 60, 15)       0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 60, 15)      0           ['positional_encoding[0][0]',
#  da)                                                              'dropout[0][0]']
#
#  layer_normalization (LayerNorm  (None, 60, 15)      30          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 60, 64)       1024        ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 60, 15)       975         ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 60, 15)       0           ['dense_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 60, 15)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 60, 15)      3795        ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 60, 15)       0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'dropout_2[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 60, 64)       1024        ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 60, 15)       975         ['dense_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 60, 15)       0           ['dense_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  global_average_pooling1d (Glob  (None, 15)          0           ['layer_normalization_3[0][0]']
#  alAveragePooling1D)
#
#  dropout_4 (Dropout)            (None, 15)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 3)            48          ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 11,756
# Trainable params: 11,756
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 클래스 가중치 계산
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# %%
print(f'class_weights: {class_weights}')
# Out:
# class_weights: {0: 9.97434135166094, 1: 0.35784265377913665, 2: 9.504038419559048}

# %%
# Focal Loss 구현
def focal_loss(gamma=2., alpha=0.25):

    def focal_loss_fixed(y_true, y_pred):
        y_true = K.cast(y_true, dtype='int32')
        y_true = K.one_hot(y_true, num_classes)
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        loss = - y_true * alpha * K.pow(1 - y_pred, gamma) * K.log(y_pred)
        loss = K.sum(loss, axis=-1)
        return K.mean(loss)
    
    return focal_loss_fixed

# %%
# 모델 컴파일
model.compile(
    loss=focal_loss(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

# %%
# 모델 체크포인트 콜백 설정
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./model_transformer2/best_model_2_10.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# %%
# 콜백 리스트에 포함
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    checkpoint_callback
]

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=512,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.8461
# Epoch 1: val_loss improved from inf to 0.03450, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 12s 36ms/step - loss: 0.0634 - accuracy: 0.8461 - val_loss: 0.0345 - val_accuracy: 0.9437
# Epoch 2/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9304
# Epoch 2: val_loss improved from 0.03450 to 0.03268, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0393 - accuracy: 0.9304 - val_loss: 0.0327 - val_accuracy: 0.9437
# Epoch 3/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9309
# Epoch 3: val_loss improved from 0.03268 to 0.03220, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0386 - accuracy: 0.9309 - val_loss: 0.0322 - val_accuracy: 0.9437
# Epoch 4/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9311
# Epoch 4: val_loss improved from 0.03220 to 0.03194, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0383 - accuracy: 0.9311 - val_loss: 0.0319 - val_accuracy: 0.9437
# Epoch 5/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9313
# Epoch 5: val_loss improved from 0.03194 to 0.03161, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0378 - accuracy: 0.9313 - val_loss: 0.0316 - val_accuracy: 0.9437
# Epoch 6/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9314
# Epoch 6: val_loss improved from 0.03161 to 0.03152, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0375 - accuracy: 0.9314 - val_loss: 0.0315 - val_accuracy: 0.9437
# Epoch 7/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9314
# Epoch 7: val_loss improved from 0.03152 to 0.03118, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0371 - accuracy: 0.9314 - val_loss: 0.0312 - val_accuracy: 0.9437
# Epoch 8/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9314
# Epoch 8: val_loss improved from 0.03118 to 0.03098, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0368 - accuracy: 0.9315 - val_loss: 0.0310 - val_accuracy: 0.9437
# Epoch 9/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9315
# Epoch 9: val_loss improved from 0.03098 to 0.03082, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0366 - accuracy: 0.9315 - val_loss: 0.0308 - val_accuracy: 0.9437
# Epoch 10/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9315
# Epoch 10: val_loss improved from 0.03082 to 0.03066, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0363 - accuracy: 0.9315 - val_loss: 0.0307 - val_accuracy: 0.9437
# Epoch 11/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9315
# Epoch 11: val_loss improved from 0.03066 to 0.03050, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0361 - accuracy: 0.9315 - val_loss: 0.0305 - val_accuracy: 0.9437
# Epoch 12/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9315
# Epoch 12: val_loss improved from 0.03050 to 0.03035, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0359 - accuracy: 0.9315 - val_loss: 0.0303 - val_accuracy: 0.9437
# Epoch 13/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9315
# Epoch 13: val_loss improved from 0.03035 to 0.03022, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0357 - accuracy: 0.9315 - val_loss: 0.0302 - val_accuracy: 0.9437
# Epoch 14/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9315
# Epoch 14: val_loss improved from 0.03022 to 0.03004, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0355 - accuracy: 0.9315 - val_loss: 0.0300 - val_accuracy: 0.9437
# Epoch 15/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9314
# Epoch 15: val_loss improved from 0.03004 to 0.02985, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0353 - accuracy: 0.9315 - val_loss: 0.0298 - val_accuracy: 0.9437
# Epoch 16/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9315
# Epoch 16: val_loss improved from 0.02985 to 0.02971, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0353 - accuracy: 0.9315 - val_loss: 0.0297 - val_accuracy: 0.9437
# Epoch 17/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9315
# Epoch 17: val_loss improved from 0.02971 to 0.02963, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 35ms/step - loss: 0.0350 - accuracy: 0.9315 - val_loss: 0.0296 - val_accuracy: 0.9437
# Epoch 18/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9315
# Epoch 18: val_loss improved from 0.02963 to 0.02947, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0349 - accuracy: 0.9315 - val_loss: 0.0295 - val_accuracy: 0.9437
# Epoch 19/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9315
# Epoch 19: val_loss improved from 0.02947 to 0.02933, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0347 - accuracy: 0.9315 - val_loss: 0.0293 - val_accuracy: 0.9437
# Epoch 20/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9315
# Epoch 20: val_loss improved from 0.02933 to 0.02919, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0346 - accuracy: 0.9315 - val_loss: 0.0292 - val_accuracy: 0.9437
# Epoch 21/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0345 - accuracy: 0.9315
# Epoch 21: val_loss improved from 0.02919 to 0.02908, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0345 - accuracy: 0.9315 - val_loss: 0.0291 - val_accuracy: 0.9437
# Epoch 22/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9315
# Epoch 22: val_loss improved from 0.02908 to 0.02888, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0342 - accuracy: 0.9315 - val_loss: 0.0289 - val_accuracy: 0.9437
# Epoch 23/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9314
# Epoch 23: val_loss improved from 0.02888 to 0.02873, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0341 - accuracy: 0.9315 - val_loss: 0.0287 - val_accuracy: 0.9437
# Epoch 24/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9315
# Epoch 24: val_loss improved from 0.02873 to 0.02865, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0340 - accuracy: 0.9315 - val_loss: 0.0287 - val_accuracy: 0.9437
# Epoch 25/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9315
# Epoch 25: val_loss improved from 0.02865 to 0.02849, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0338 - accuracy: 0.9315 - val_loss: 0.0285 - val_accuracy: 0.9437
# Epoch 26/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9315
# Epoch 26: val_loss improved from 0.02849 to 0.02846, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0337 - accuracy: 0.9315 - val_loss: 0.0285 - val_accuracy: 0.9437
# Epoch 27/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9315
# Epoch 27: val_loss improved from 0.02846 to 0.02827, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0336 - accuracy: 0.9315 - val_loss: 0.0283 - val_accuracy: 0.9437
# Epoch 28/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9315
# Epoch 28: val_loss improved from 0.02827 to 0.02818, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 8s 33ms/step - loss: 0.0335 - accuracy: 0.9315 - val_loss: 0.0282 - val_accuracy: 0.9437
# Epoch 29/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9315
# Epoch 29: val_loss improved from 0.02818 to 0.02811, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0334 - accuracy: 0.9315 - val_loss: 0.0281 - val_accuracy: 0.9437
# Epoch 30/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9315
# Epoch 30: val_loss improved from 0.02811 to 0.02797, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0333 - accuracy: 0.9315 - val_loss: 0.0280 - val_accuracy: 0.9437
# Epoch 31/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9315
# Epoch 31: val_loss improved from 0.02797 to 0.02787, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0331 - accuracy: 0.9315 - val_loss: 0.0279 - val_accuracy: 0.9437
# Epoch 32/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0330 - accuracy: 0.9315
# Epoch 32: val_loss improved from 0.02787 to 0.02779, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0330 - accuracy: 0.9315 - val_loss: 0.0278 - val_accuracy: 0.9437
# Epoch 33/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9315
# Epoch 33: val_loss improved from 0.02779 to 0.02777, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0330 - accuracy: 0.9315 - val_loss: 0.0278 - val_accuracy: 0.9437
# Epoch 34/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9315
# Epoch 34: val_loss improved from 0.02777 to 0.02762, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0329 - accuracy: 0.9315 - val_loss: 0.0276 - val_accuracy: 0.9437
# Epoch 35/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9315
# Epoch 35: val_loss did not improve from 0.02762
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0328 - accuracy: 0.9315 - val_loss: 0.0277 - val_accuracy: 0.9437
# Epoch 36/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9315
# Epoch 36: val_loss improved from 0.02762 to 0.02754, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0327 - accuracy: 0.9315 - val_loss: 0.0275 - val_accuracy: 0.9437
# Epoch 37/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9315
# Epoch 37: val_loss improved from 0.02754 to 0.02752, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0327 - accuracy: 0.9315 - val_loss: 0.0275 - val_accuracy: 0.9437
# Epoch 38/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9315
# Epoch 38: val_loss improved from 0.02752 to 0.02745, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0325 - accuracy: 0.9315 - val_loss: 0.0275 - val_accuracy: 0.9437
# Epoch 39/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9316
# Epoch 39: val_loss improved from 0.02745 to 0.02733, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0324 - accuracy: 0.9315 - val_loss: 0.0273 - val_accuracy: 0.9437
# Epoch 40/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9316
# Epoch 40: val_loss did not improve from 0.02733
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0324 - accuracy: 0.9315 - val_loss: 0.0275 - val_accuracy: 0.9437
# Epoch 41/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9315
# Epoch 41: val_loss improved from 0.02733 to 0.02728, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0324 - accuracy: 0.9315 - val_loss: 0.0273 - val_accuracy: 0.9437
# Epoch 42/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9315
# Epoch 42: val_loss did not improve from 0.02728
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0323 - accuracy: 0.9315 - val_loss: 0.0273 - val_accuracy: 0.9437
# Epoch 43/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9315
# Epoch 43: val_loss improved from 0.02728 to 0.02723, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0323 - accuracy: 0.9315 - val_loss: 0.0272 - val_accuracy: 0.9437
# Epoch 44/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9315
# Epoch 44: val_loss improved from 0.02723 to 0.02710, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0322 - accuracy: 0.9315 - val_loss: 0.0271 - val_accuracy: 0.9437
# Epoch 45/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9315
# Epoch 45: val_loss improved from 0.02710 to 0.02707, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0322 - accuracy: 0.9315 - val_loss: 0.0271 - val_accuracy: 0.9437
# Epoch 46/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9315
# Epoch 46: val_loss did not improve from 0.02707
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0322 - accuracy: 0.9315 - val_loss: 0.0272 - val_accuracy: 0.9437
# Epoch 47/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9315
# Epoch 47: val_loss improved from 0.02707 to 0.02702, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0321 - accuracy: 0.9315 - val_loss: 0.0270 - val_accuracy: 0.9437
# Epoch 48/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9315
# Epoch 48: val_loss did not improve from 0.02702
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0321 - accuracy: 0.9315 - val_loss: 0.0270 - val_accuracy: 0.9437
# Epoch 49/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9315
# Epoch 49: val_loss did not improve from 0.02702
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0321 - accuracy: 0.9315 - val_loss: 0.0271 - val_accuracy: 0.9437
# Epoch 50/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9315
# Epoch 50: val_loss improved from 0.02702 to 0.02700, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0320 - accuracy: 0.9315 - val_loss: 0.0270 - val_accuracy: 0.9437
# Epoch 51/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9315
# Epoch 51: val_loss improved from 0.02700 to 0.02698, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0270 - val_accuracy: 0.9437
# Epoch 52/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9315
# Epoch 52: val_loss improved from 0.02698 to 0.02692, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 53/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9315
# Epoch 53: val_loss did not improve from 0.02692
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0270 - val_accuracy: 0.9437
# Epoch 54/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9316
# Epoch 54: val_loss did not improve from 0.02692
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 55/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9315
# Epoch 55: val_loss did not improve from 0.02692
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 56/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9315
# Epoch 56: val_loss improved from 0.02692 to 0.02688, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0319 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 57/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9314
# Epoch 57: val_loss improved from 0.02688 to 0.02687, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0318 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 58/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9315
# Epoch 58: val_loss improved from 0.02687 to 0.02683, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0318 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 59/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9315
# Epoch 59: val_loss did not improve from 0.02683
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0318 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 60/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9315
# Epoch 60: val_loss did not improve from 0.02683
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0318 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 61/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 61: val_loss did not improve from 0.02683
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 62/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9315
# Epoch 62: val_loss did not improve from 0.02683
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 63/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 63: val_loss improved from 0.02683 to 0.02682, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 64/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 64: val_loss improved from 0.02682 to 0.02676, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 65/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 65: val_loss improved from 0.02676 to 0.02675, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 66/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 66: val_loss improved from 0.02675 to 0.02673, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 67/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 67: val_loss did not improve from 0.02673
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 68/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 68: val_loss did not improve from 0.02673
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 69/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 69: val_loss improved from 0.02673 to 0.02667, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 70/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 70: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 71/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 71: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 72/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 72: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 73/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 73: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 74/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 74: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 75/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9315
# Epoch 75: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0317 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 76/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 76: val_loss did not improve from 0.02667
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0269 - val_accuracy: 0.9437
# Epoch 77/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 77: val_loss improved from 0.02667 to 0.02664, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0266 - val_accuracy: 0.9437
# Epoch 78/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 78: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 79/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 79: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 80/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9315
# Epoch 80: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0316 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 81/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 81: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 82/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 82: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 83/100
# 256/256 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 83: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 84/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 84: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 85/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 85: val_loss did not improve from 0.02664
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 86/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 86: val_loss improved from 0.02664 to 0.02662, saving model to ./model_transformer2\best_model_2_10.h5
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0266 - val_accuracy: 0.9437
# Epoch 87/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 87: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 88/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 88: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 89/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 89: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0268 - val_accuracy: 0.9437
# Epoch 90/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 90: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 91/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 91: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 92/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 92: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 93/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 93: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 33ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 94/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 94: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 95/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 95: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437
# Epoch 96/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9315
# Epoch 96: val_loss did not improve from 0.02662
# 256/256 [==============================] - 9s 34ms/step - loss: 0.0315 - accuracy: 0.9315 - val_loss: 0.0267 - val_accuracy: 0.9437

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 875/875 [==============================] - 7s 8ms/step - loss: 0.1061 - accuracy: 0.7201
# Test Accuracy: 0.7201

# %%
# 자세한 성능 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_classes))
# Out:
# 875/875 [==============================] - 6s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3907
#            1       0.72      1.00      0.84     20156
#            2       0.00      0.00      0.00      3927
#
#     accuracy                           0.72     27990
#    macro avg       0.24      0.33      0.28     27990
# weighted avg       0.52      0.72      0.60     27990
# c:\ProgramData\anaconda3\envs\final_tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\anaconda3\envs\final_tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\anaconda3\envs\final_tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
# 혼동 행렬 계산 및 시각화
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
# 정확도 시각화
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# 손실 시각화
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

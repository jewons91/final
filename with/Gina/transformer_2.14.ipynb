# %% [markdown]
# #### 2.11 copy
# #### 추가적인 기술 지표 도입

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow.keras.backend as K

# %%
# 데이터 로드
data = pd.read_csv('./000660.csv')

# 데이터 칼럼명 변경
data = data.rename(
    columns={
        '시가': 'Open',
        '고가': 'High',
        '저가': 'Low',
        '종가': 'Close',
        '거래량': 'Total_Volume',
        '매도량': 'Sell_Volume',
        '매수량': 'Buy_Volume'
    })

# %%
# 결측치 제거
data = data.dropna()

# %%
# 특성 선택
price_features = ['Open', 'High', 'Low', 'Close']
volume_features = ['Buy_Volume', 'Sell_Volume', 'Total_Volume']
features = price_features + volume_features

# %%
# 거래량 강도 계산
data['Volume_Intensity'] = data['Buy_Volume'] - data['Sell_Volume']
data['Volume_Intensity_Ratio'] = data['Volume_Intensity'] / (data['Total_Volume'] + 1e-5)
data['Buy_Sell_Ratio'] = data['Buy_Volume'] / (data['Sell_Volume'] + 1e-5)

# %%
# 새로운 특성들을 특성 리스트에 추가
features.extend(['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio'])

# %%
# 이동 평균선 추가
data['MA_5'] = data['Close'].rolling(window=5).mean()
data['MA_20'] = data['Close'].rolling(window=20).mean()
data['MA_60'] = data['Close'].rolling(window=60).mean()
data['MA_5_20_Diff'] = data['MA_5'] - data['MA_20']
data['MA_20_60_Diff'] = data['MA_20'] - data['MA_60']

# %%
# 추가된 특성을 특성 리스트에 포함
features.extend(['MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff'])

# %%
# 이동 평균선 계산 후 결측치 제거
data = data.dropna()

# %%
# RSI 계산
delta = data['Close'].diff()
up = delta.clip(lower=0)
down = -1 * delta.clip(upper=0)
ema_up = up.ewm(com=13, adjust=False).mean()
ema_down = down.ewm(com=13, adjust=False).mean()
rs = ema_up / ema_down
data['RSI'] = 100 - (100 / (1 + rs))

# MACD 계산
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2
data['Signal'] = data['MACD'].ewm(span=9, adjust=False).mean()

# 볼린저 밴드 계산
data['BB_upper'] = data['Close'].rolling(window=20).mean() + (data['Close'].rolling(window=20).std() * 2)
data['BB_lower'] = data['Close'].rolling(window=20).mean() - (data['Close'].rolling(window=20).std() * 2)

# 결측치 제거
data = data.dropna()

# 추가된 특성을 특성 리스트에 포함
features.extend(['RSI', 'MACD', 'Signal', 'BB_upper', 'BB_lower'])

# %%
# 가격 급변 레이블링
price_threshold = 0.002  # 0.21% 이상 변동 시 변동으로 간주

data['Price_Change'] = data['Close'].pct_change()
data = data.dropna()

def label_price_change(change):
    if change >= price_threshold:
        return 2  # 상승
    elif change <= -price_threshold:
        return 0  # 하락
    else:
        return 1  # 보합

data['Price_Label'] = data['Price_Change'].apply(label_price_change)

# %%
# 결측치 제거 (최종)
data = data.dropna()

# %%
# 스케일러 딕셔너리 생성
scalers = {}

# %%
# 'Close' 열의 평균과 표준편차 계산
mean_close = data['Close'].mean()
std_close = data['Close'].std()

# 가격 관련 모든 특성에 동일한 평균과 표준편차 적용하여 스케일링
price_related_features = ['Close', 'Open', 'High', 'Low', 'MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff']
data[price_related_features] = (data[price_related_features] - mean_close) / std_close

# %%
# 거래량 관련 특성 스케일링
for feature in volume_features + ['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio']:
    scaler = RobustScaler()
    data[feature] = scaler.fit_transform(data[[feature]])
    scalers[feature] = scaler

# %%
# 시퀀스 생성 함수 정의
def create_sequences(data, sequence_length, target):
    X = []
    y = []
    data_values = data[features].values
    labels = data[target].values
    for i in range(len(data_values) - sequence_length):
        X.append(data_values[i:i+sequence_length])
        y.append(labels[i+sequence_length])
    return np.array(X), np.array(y)

# %%
# 데이터 생성
sequence_length = 20  # 시퀀스 길이
X, y = create_sequences(data, sequence_length, target='Price_Label')

# %%
# 시간 순서대로 데이터 분할
train_size = int(len(X) * 0.7)
val_size = int(len(X) * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size+val_size]
y_val = y[train_size:train_size+val_size]

X_test = X[train_size+val_size:]
y_test = y[train_size+val_size:]

# %%
# 클래스 분포 확인
unique, counts = np.unique(y_train, return_counts=True)
print("클래스 분포:", dict(zip(unique, counts)))
# Out:
# 클래스 분포: {0: 4437, 1: 121537, 2: 4646}

# %%
# 하이퍼 파라미터 설정
d_model = X_train.shape[2]
num_heads = 4
ff_dim = 64
num_layers = 2
dropout_rate = 0.1
num_classes = 3  # 레이블 클래스 수

# %%
# 포지셔널 인코딩 정의
class PositionalEncoding(layers.Layer):
    def __init__(self, sequence_length, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(sequence_length, d_model)
    
    def get_config(self):
        config = super().get_config().copy()
        return config
    
    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            np.arange(position)[:, np.newaxis],
            np.arange(d_model)[np.newaxis, :],
            d_model)
        
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)
    
    def get_angles(self, pos, i, d_model):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
        return pos * angle_rates
    
    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
# 트랜스포머 블록 정의
def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(inputs, inputs)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)
    
    # Feed Forward Network
    ffn_output = layers.Dense(ff_dim, activation='gelu', kernel_regularizer=regularizers.l2(1e-4))(out1)
    ffn_output = layers.Dense(head_size)(ffn_output)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

# %%
# 모델 정의
def create_model():
    inputs = layers.Input(shape=(sequence_length, d_model))
    x = PositionalEncoding(sequence_length, d_model)(inputs)
    
    for _ in range(num_layers):
        x = transformer_block(x, d_model, num_heads, ff_dim, dropout_rate)
    
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 60, 15)]     0           []
#
#  positional_encoding (Positiona  (None, 60, 15)      0           ['input_1[0][0]']
#  lEncoding)
#
#  multi_head_attention (MultiHea  (None, 60, 15)      3795        ['positional_encoding[0][0]',
#  dAttention)                                                      'positional_encoding[0][0]']
#
#  dropout (Dropout)              (None, 60, 15)       0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 60, 15)      0           ['positional_encoding[0][0]',
#  da)                                                              'dropout[0][0]']
#
#  layer_normalization (LayerNorm  (None, 60, 15)      30          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 60, 64)       1024        ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 60, 15)       975         ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 60, 15)       0           ['dense_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 60, 15)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 60, 15)      3795        ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 60, 15)       0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'dropout_2[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 60, 64)       1024        ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 60, 15)       975         ['dense_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 60, 15)       0           ['dense_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  global_average_pooling1d (Glob  (None, 15)          0           ['layer_normalization_3[0][0]']
#  alAveragePooling1D)
#
#  dropout_4 (Dropout)            (None, 15)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 3)            48          ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 11,756
# Trainable params: 11,756
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 클래스 가중치 계산
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# %%
class_weights
# Out:
# {0: 9.812936668920441, 1: 0.35824481433637495, 2: 9.371502367628068}

# %%
# 모델 컴파일
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

# %%
# 모델 체크포인트 콜백 설정
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./model_transformer2/best_model_2_14.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# %%
# 콜백 리스트에 포함
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    checkpoint_callback
]

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=512,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1836 - accuracy: 0.3385
# Epoch 1: val_loss improved from inf to 0.15894, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 14s 42ms/step - loss: 0.1835 - accuracy: 0.3385 - val_loss: 0.1589 - val_accuracy: 0.1680
# Epoch 2/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1739 - accuracy: 0.3402
# Epoch 2: val_loss improved from 0.15894 to 0.15782, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 11s 42ms/step - loss: 0.1739 - accuracy: 0.3401 - val_loss: 0.1578 - val_accuracy: 0.0921
# Epoch 3/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1719 - accuracy: 0.3231
# Epoch 3: val_loss improved from 0.15782 to 0.15602, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1720 - accuracy: 0.3232 - val_loss: 0.1560 - val_accuracy: 0.3014
# Epoch 4/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1712 - accuracy: 0.3227
# Epoch 4: val_loss did not improve from 0.15602
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1712 - accuracy: 0.3226 - val_loss: 0.1562 - val_accuracy: 0.0977
# Epoch 5/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.3152
# Epoch 5: val_loss improved from 0.15602 to 0.15510, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1705 - accuracy: 0.3151 - val_loss: 0.1551 - val_accuracy: 0.1650
# Epoch 6/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1703 - accuracy: 0.3091
# Epoch 6: val_loss improved from 0.15510 to 0.15502, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1703 - accuracy: 0.3091 - val_loss: 0.1550 - val_accuracy: 0.1441
# Epoch 7/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1697 - accuracy: 0.3038
# Epoch 7: val_loss improved from 0.15502 to 0.15452, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1696 - accuracy: 0.3040 - val_loss: 0.1545 - val_accuracy: 0.2339
# Epoch 8/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.2970
# Epoch 8: val_loss did not improve from 0.15452
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1695 - accuracy: 0.2970 - val_loss: 0.1546 - val_accuracy: 0.1349
# Epoch 9/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1693 - accuracy: 0.3032
# Epoch 9: val_loss improved from 0.15452 to 0.15436, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1693 - accuracy: 0.3032 - val_loss: 0.1544 - val_accuracy: 0.1822
# Epoch 10/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1694 - accuracy: 0.2911
# Epoch 10: val_loss improved from 0.15436 to 0.15414, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1693 - accuracy: 0.2912 - val_loss: 0.1541 - val_accuracy: 0.2313
# Epoch 11/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.3097
# Epoch 11: val_loss did not improve from 0.15414
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1691 - accuracy: 0.3097 - val_loss: 0.1543 - val_accuracy: 0.0949
# Epoch 12/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1689 - accuracy: 0.2985
# Epoch 12: val_loss improved from 0.15414 to 0.15407, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1689 - accuracy: 0.2986 - val_loss: 0.1541 - val_accuracy: 0.1806
# Epoch 13/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1689 - accuracy: 0.3223
# Epoch 13: val_loss improved from 0.15407 to 0.15380, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1689 - accuracy: 0.3224 - val_loss: 0.1538 - val_accuracy: 0.2524
# Epoch 14/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1687 - accuracy: 0.2969
# Epoch 14: val_loss did not improve from 0.15380
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1686 - accuracy: 0.2970 - val_loss: 0.1539 - val_accuracy: 0.1568
# Epoch 15/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1684 - accuracy: 0.2901
# Epoch 15: val_loss did not improve from 0.15380
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1684 - accuracy: 0.2901 - val_loss: 0.1540 - val_accuracy: 0.0500
# Epoch 16/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1682 - accuracy: 0.2891
# Epoch 16: val_loss did not improve from 0.15380
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1683 - accuracy: 0.2892 - val_loss: 0.1538 - val_accuracy: 0.1195
# Epoch 17/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.2602
# Epoch 17: val_loss improved from 0.15380 to 0.15356, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1681 - accuracy: 0.2604 - val_loss: 0.1536 - val_accuracy: 0.1777
# Epoch 18/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.2739
# Epoch 18: val_loss did not improve from 0.15356
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1676 - accuracy: 0.2739 - val_loss: 0.1540 - val_accuracy: 0.0396
# Epoch 19/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.3122
# Epoch 19: val_loss improved from 0.15356 to 0.15328, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1677 - accuracy: 0.3123 - val_loss: 0.1533 - val_accuracy: 0.2019
# Epoch 20/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1676 - accuracy: 0.2664
# Epoch 20: val_loss did not improve from 0.15328
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1676 - accuracy: 0.2663 - val_loss: 0.1535 - val_accuracy: 0.0593
# Epoch 21/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.3050
# Epoch 21: val_loss did not improve from 0.15328
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1675 - accuracy: 0.3050 - val_loss: 0.1536 - val_accuracy: 0.0320
# Epoch 22/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.2672
# Epoch 22: val_loss did not improve from 0.15328
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1678 - accuracy: 0.2672 - val_loss: 0.1535 - val_accuracy: 0.0365
# Epoch 23/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.2535
# Epoch 23: val_loss improved from 0.15328 to 0.15323, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1675 - accuracy: 0.2535 - val_loss: 0.1532 - val_accuracy: 0.0432
# Epoch 24/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.2325
# Epoch 24: val_loss improved from 0.15323 to 0.15282, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1673 - accuracy: 0.2326 - val_loss: 0.1528 - val_accuracy: 0.1665
# Epoch 25/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.2655
# Epoch 25: val_loss did not improve from 0.15282
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1674 - accuracy: 0.2654 - val_loss: 0.1531 - val_accuracy: 0.0512
# Epoch 26/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.2793
# Epoch 26: val_loss did not improve from 0.15282
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1672 - accuracy: 0.2792 - val_loss: 0.1533 - val_accuracy: 0.0310
# Epoch 27/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.2371
# Epoch 27: val_loss did not improve from 0.15282
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1671 - accuracy: 0.2371 - val_loss: 0.1530 - val_accuracy: 0.0374
# Epoch 28/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1666 - accuracy: 0.2753
# Epoch 28: val_loss did not improve from 0.15282
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1668 - accuracy: 0.2753 - val_loss: 0.1529 - val_accuracy: 0.0321
# Epoch 29/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1670 - accuracy: 0.1986
# Epoch 29: val_loss improved from 0.15282 to 0.15244, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1670 - accuracy: 0.1986 - val_loss: 0.1524 - val_accuracy: 0.0787
# Epoch 30/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.2182
# Epoch 30: val_loss did not improve from 0.15244
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1669 - accuracy: 0.2182 - val_loss: 0.1525 - val_accuracy: 0.0582
# Epoch 31/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.2531
# Epoch 31: val_loss did not improve from 0.15244
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1669 - accuracy: 0.2531 - val_loss: 0.1526 - val_accuracy: 0.0336
# Epoch 32/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1666 - accuracy: 0.2374
# Epoch 32: val_loss improved from 0.15244 to 0.15235, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1667 - accuracy: 0.2373 - val_loss: 0.1523 - val_accuracy: 0.0329
# Epoch 33/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1666 - accuracy: 0.2194
# Epoch 33: val_loss improved from 0.15235 to 0.15213, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1666 - accuracy: 0.2196 - val_loss: 0.1521 - val_accuracy: 0.2265
# Epoch 34/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1667 - accuracy: 0.2448
# Epoch 34: val_loss improved from 0.15213 to 0.15198, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1666 - accuracy: 0.2450 - val_loss: 0.1520 - val_accuracy: 0.2492
# Epoch 35/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1668 - accuracy: 0.2436
# Epoch 35: val_loss did not improve from 0.15198
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1668 - accuracy: 0.2435 - val_loss: 0.1521 - val_accuracy: 0.0529
# Epoch 36/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1664 - accuracy: 0.2500
# Epoch 36: val_loss improved from 0.15198 to 0.15189, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1665 - accuracy: 0.2500 - val_loss: 0.1519 - val_accuracy: 0.0668
# Epoch 37/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.2072
# Epoch 37: val_loss did not improve from 0.15189
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1664 - accuracy: 0.2072 - val_loss: 0.1520 - val_accuracy: 0.0358
# Epoch 38/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.3060
# Epoch 38: val_loss did not improve from 0.15189
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1663 - accuracy: 0.3060 - val_loss: 0.1519 - val_accuracy: 0.0320
# Epoch 39/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.1926
# Epoch 39: val_loss improved from 0.15189 to 0.15171, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1663 - accuracy: 0.1927 - val_loss: 0.1517 - val_accuracy: 0.1133
# Epoch 40/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.2429
# Epoch 40: val_loss improved from 0.15171 to 0.15163, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1659 - accuracy: 0.2429 - val_loss: 0.1516 - val_accuracy: 0.0700
# Epoch 41/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.2353
# Epoch 41: val_loss improved from 0.15163 to 0.15151, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1658 - accuracy: 0.2353 - val_loss: 0.1515 - val_accuracy: 0.0683
# Epoch 42/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1664 - accuracy: 0.2118
# Epoch 42: val_loss improved from 0.15151 to 0.15144, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1664 - accuracy: 0.2118 - val_loss: 0.1514 - val_accuracy: 0.1204
# Epoch 43/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.1999
# Epoch 43: val_loss did not improve from 0.15144
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1660 - accuracy: 0.1999 - val_loss: 0.1515 - val_accuracy: 0.0429
# Epoch 44/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.1439
# Epoch 44: val_loss improved from 0.15144 to 0.15136, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1662 - accuracy: 0.1439 - val_loss: 0.1514 - val_accuracy: 0.0487
# Epoch 45/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.2216
# Epoch 45: val_loss did not improve from 0.15136
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1658 - accuracy: 0.2215 - val_loss: 0.1514 - val_accuracy: 0.0352
# Epoch 46/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.1577
# Epoch 46: val_loss did not improve from 0.15136
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1657 - accuracy: 0.1576 - val_loss: 0.1514 - val_accuracy: 0.0329
# Epoch 47/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.2130
# Epoch 47: val_loss improved from 0.15136 to 0.15119, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1657 - accuracy: 0.2131 - val_loss: 0.1512 - val_accuracy: 0.0790
# Epoch 48/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.1793
# Epoch 48: val_loss did not improve from 0.15119
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1658 - accuracy: 0.1793 - val_loss: 0.1513 - val_accuracy: 0.0357
# Epoch 49/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.1774
# Epoch 49: val_loss did not improve from 0.15119
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1656 - accuracy: 0.1773 - val_loss: 0.1514 - val_accuracy: 0.0308
# Epoch 50/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.2055
# Epoch 50: val_loss improved from 0.15119 to 0.15111, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1658 - accuracy: 0.2055 - val_loss: 0.1511 - val_accuracy: 0.0352
# Epoch 51/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.2014
# Epoch 51: val_loss improved from 0.15111 to 0.15107, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1655 - accuracy: 0.2014 - val_loss: 0.1511 - val_accuracy: 0.0387
# Epoch 52/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.1395
# Epoch 52: val_loss improved from 0.15107 to 0.15101, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1657 - accuracy: 0.1395 - val_loss: 0.1510 - val_accuracy: 0.0393
# Epoch 53/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.2022
# Epoch 53: val_loss improved from 0.15101 to 0.15091, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1655 - accuracy: 0.2021 - val_loss: 0.1509 - val_accuracy: 0.0491
# Epoch 54/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1652 - accuracy: 0.2131
# Epoch 54: val_loss did not improve from 0.15091
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1652 - accuracy: 0.2130 - val_loss: 0.1510 - val_accuracy: 0.0307
# Epoch 55/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1656 - accuracy: 0.1235
# Epoch 55: val_loss did not improve from 0.15091
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1656 - accuracy: 0.1235 - val_loss: 0.1510 - val_accuracy: 0.0308
# Epoch 56/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1651 - accuracy: 0.1497
# Epoch 56: val_loss improved from 0.15091 to 0.15081, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1651 - accuracy: 0.1497 - val_loss: 0.1508 - val_accuracy: 0.0428
# Epoch 57/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.1963
# Epoch 57: val_loss did not improve from 0.15081
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1654 - accuracy: 0.1962 - val_loss: 0.1509 - val_accuracy: 0.0328
# Epoch 58/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.1171
# Epoch 58: val_loss did not improve from 0.15081
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1653 - accuracy: 0.1170 - val_loss: 0.1508 - val_accuracy: 0.0306
# Epoch 59/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.1074
# Epoch 59: val_loss improved from 0.15081 to 0.15069, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1655 - accuracy: 0.1075 - val_loss: 0.1507 - val_accuracy: 0.0512
# Epoch 60/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.1649
# Epoch 60: val_loss did not improve from 0.15069
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1652 - accuracy: 0.1649 - val_loss: 0.1508 - val_accuracy: 0.0311
# Epoch 61/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.1436
# Epoch 61: val_loss improved from 0.15069 to 0.15068, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 11s 41ms/step - loss: 0.1649 - accuracy: 0.1436 - val_loss: 0.1507 - val_accuracy: 0.0345
# Epoch 62/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1652 - accuracy: 0.2183
# Epoch 62: val_loss did not improve from 0.15068
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1652 - accuracy: 0.2183 - val_loss: 0.1507 - val_accuracy: 0.0346
# Epoch 63/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.1130
# Epoch 63: val_loss improved from 0.15068 to 0.15064, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1652 - accuracy: 0.1130 - val_loss: 0.1506 - val_accuracy: 0.0328
# Epoch 64/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.0678
# Epoch 64: val_loss improved from 0.15064 to 0.15062, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1655 - accuracy: 0.0678 - val_loss: 0.1506 - val_accuracy: 0.0311
# Epoch 65/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.1324
# Epoch 65: val_loss improved from 0.15062 to 0.15049, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1655 - accuracy: 0.1323 - val_loss: 0.1505 - val_accuracy: 0.0337
# Epoch 66/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1652 - accuracy: 0.0468
# Epoch 66: val_loss improved from 0.15049 to 0.15043, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1651 - accuracy: 0.0469 - val_loss: 0.1504 - val_accuracy: 0.0335
# Epoch 67/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0856
# Epoch 67: val_loss did not improve from 0.15043
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1649 - accuracy: 0.0856 - val_loss: 0.1506 - val_accuracy: 0.0304
# Epoch 68/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.1406
# Epoch 68: val_loss did not improve from 0.15043
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1649 - accuracy: 0.1406 - val_loss: 0.1505 - val_accuracy: 0.0315
# Epoch 69/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.1252
# Epoch 69: val_loss improved from 0.15043 to 0.15041, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 11s 41ms/step - loss: 0.1649 - accuracy: 0.1252 - val_loss: 0.1504 - val_accuracy: 0.0336
# Epoch 70/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0531
# Epoch 70: val_loss improved from 0.15041 to 0.15033, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1650 - accuracy: 0.0531 - val_loss: 0.1503 - val_accuracy: 0.0341
# Epoch 71/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1652 - accuracy: 0.0495
# Epoch 71: val_loss improved from 0.15033 to 0.15031, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1651 - accuracy: 0.0495 - val_loss: 0.1503 - val_accuracy: 0.0329
# Epoch 72/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0882
# Epoch 72: val_loss did not improve from 0.15031
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1647 - accuracy: 0.0882 - val_loss: 0.1504 - val_accuracy: 0.0325
# Epoch 73/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0823
# Epoch 73: val_loss did not improve from 0.15031
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1649 - accuracy: 0.0823 - val_loss: 0.1505 - val_accuracy: 0.0304
# Epoch 74/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.0459
# Epoch 74: val_loss improved from 0.15031 to 0.15031, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 11s 41ms/step - loss: 0.1650 - accuracy: 0.0459 - val_loss: 0.1503 - val_accuracy: 0.0320
# Epoch 75/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.1715
# Epoch 75: val_loss did not improve from 0.15031
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1649 - accuracy: 0.1714 - val_loss: 0.1503 - val_accuracy: 0.0317
# Epoch 76/100
# 254/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0375
# Epoch 76: val_loss did not improve from 0.15031
# 256/256 [==============================] - 10s 39ms/step - loss: 0.1650 - accuracy: 0.0375 - val_loss: 0.1504 - val_accuracy: 0.0307
# Epoch 77/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0393
# Epoch 77: val_loss improved from 0.15031 to 0.15030, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1648 - accuracy: 0.0393 - val_loss: 0.1503 - val_accuracy: 0.0312
# Epoch 78/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.0524
# Epoch 78: val_loss did not improve from 0.15030
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1649 - accuracy: 0.0523 - val_loss: 0.1503 - val_accuracy: 0.0311
# Epoch 79/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0505
# Epoch 79: val_loss improved from 0.15030 to 0.15028, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1645 - accuracy: 0.0505 - val_loss: 0.1503 - val_accuracy: 0.0310
# Epoch 80/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.0763
# Epoch 80: val_loss improved from 0.15028 to 0.15027, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1646 - accuracy: 0.0763 - val_loss: 0.1503 - val_accuracy: 0.0307
# Epoch 81/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0997
# Epoch 81: val_loss improved from 0.15027 to 0.15020, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1648 - accuracy: 0.0996 - val_loss: 0.1502 - val_accuracy: 0.0317
# Epoch 82/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0390
# Epoch 82: val_loss improved from 0.15020 to 0.15020, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1647 - accuracy: 0.0390 - val_loss: 0.1502 - val_accuracy: 0.0322
# Epoch 83/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1643 - accuracy: 0.0446
# Epoch 83: val_loss improved from 0.15020 to 0.15017, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1645 - accuracy: 0.0446 - val_loss: 0.1502 - val_accuracy: 0.0324
# Epoch 84/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0369
# Epoch 84: val_loss improved from 0.15017 to 0.15012, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1645 - accuracy: 0.0369 - val_loss: 0.1501 - val_accuracy: 0.0325
# Epoch 85/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0419
# Epoch 85: val_loss did not improve from 0.15012
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1645 - accuracy: 0.0419 - val_loss: 0.1502 - val_accuracy: 0.0304
# Epoch 86/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0351
# Epoch 86: val_loss did not improve from 0.15012
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1647 - accuracy: 0.0350 - val_loss: 0.1502 - val_accuracy: 0.0309
# Epoch 87/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0369
# Epoch 87: val_loss improved from 0.15012 to 0.15012, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 11s 41ms/step - loss: 0.1649 - accuracy: 0.0369 - val_loss: 0.1501 - val_accuracy: 0.0314
# Epoch 88/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0362
# Epoch 88: val_loss improved from 0.15012 to 0.15011, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1647 - accuracy: 0.0362 - val_loss: 0.1501 - val_accuracy: 0.0316
# Epoch 89/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0374
# Epoch 89: val_loss improved from 0.15011 to 0.15003, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1645 - accuracy: 0.0374 - val_loss: 0.1500 - val_accuracy: 0.0340
# Epoch 90/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0420
# Epoch 90: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1645 - accuracy: 0.0420 - val_loss: 0.1501 - val_accuracy: 0.0320
# Epoch 91/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0365
# Epoch 91: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1647 - accuracy: 0.0365 - val_loss: 0.1501 - val_accuracy: 0.0315
# Epoch 92/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.0409
# Epoch 92: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1646 - accuracy: 0.0409 - val_loss: 0.1501 - val_accuracy: 0.0318
# Epoch 93/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1651 - accuracy: 0.0357
# Epoch 93: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1650 - accuracy: 0.0356 - val_loss: 0.1502 - val_accuracy: 0.0298
# Epoch 94/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.0401
# Epoch 94: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1644 - accuracy: 0.0400 - val_loss: 0.1500 - val_accuracy: 0.0325
# Epoch 95/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.0361
# Epoch 95: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1649 - accuracy: 0.0360 - val_loss: 0.1501 - val_accuracy: 0.0312
# Epoch 96/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.0438
# Epoch 96: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1645 - accuracy: 0.0438 - val_loss: 0.1502 - val_accuracy: 0.0305
# Epoch 97/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1644 - accuracy: 0.0348
# Epoch 97: val_loss did not improve from 0.15003
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1644 - accuracy: 0.0348 - val_loss: 0.1501 - val_accuracy: 0.0323
# Epoch 98/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1644 - accuracy: 0.0348
# Epoch 98: val_loss improved from 0.15003 to 0.15001, saving model to ./model_transformer2\best_model_2_11.h5
# 256/256 [==============================] - 10s 41ms/step - loss: 0.1643 - accuracy: 0.0348 - val_loss: 0.1500 - val_accuracy: 0.0326
# Epoch 99/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.0358
# Epoch 99: val_loss did not improve from 0.15001
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1647 - accuracy: 0.0358 - val_loss: 0.1501 - val_accuracy: 0.0291
# Epoch 100/100
# 255/256 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.0414
# Epoch 100: val_loss did not improve from 0.15001
# 256/256 [==============================] - 10s 40ms/step - loss: 0.1646 - accuracy: 0.0414 - val_loss: 0.1501 - val_accuracy: 0.0300

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 875/875 [==============================] - 7s 8ms/step - loss: 0.5049 - accuracy: 0.1537
# Test Accuracy: 0.1537

# %%
# 자세한 성능 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_classes))
# Out:
# 875/875 [==============================] - 6s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.11      0.38      0.17      4180
#            1       0.49      0.01      0.03     19636
#            2       0.19      0.58      0.29      4175
#
#     accuracy                           0.15     27991
#    macro avg       0.26      0.33      0.16     27991
# weighted avg       0.39      0.15      0.09     27991

# %%
import matplotlib.pyplot as plt
# 혼동 행렬 계산 및 시각화
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
# 정확도 시각화
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# 손실 시각화
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

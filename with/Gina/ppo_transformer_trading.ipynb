# %%
import numpy as np
import pandas as pd
import yfinance as yf
import gym
from gym import spaces
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
import warnings

# UserWarning 무시 (필요 시 제거 가능)
warnings.filterwarnings("ignore", category=UserWarning)

# 디바이스 설정 (GPU 사용 여부 확인)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Transformer 모듈 정의 (8개의 TransformerEncoderLayer 스택)
class TimesNet(nn.Module):
    def __init__(self, input_dim, seq_length, embed_dim=128, num_heads=4, num_layers=8, dropout=0.1):
        super(TimesNet, self).__init__()
        self.seq_length = seq_length
        self.embed_dim = embed_dim
        self.input_linear = nn.Linear(input_dim, embed_dim)
        
        # TransformerEncoderLayer에 batch_first=True 설정
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim, 
            nhead=num_heads, 
            dropout=dropout,
            batch_first=True  # batch_first 설정
        )
        
        # 8개의 TransformerEncoderLayer를 쌓기 위해 num_layers=8로 설정
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        self.output_linear = nn.Linear(embed_dim, embed_dim)
        self.activation = nn.ReLU()
        self.layer_norm = nn.LayerNorm(embed_dim)  # LayerNorm 사용

    def forward(self, x):
        """
        x: [batch_size, seq_length, input_dim]
        """
        x = self.input_linear(x)  # [batch_size, seq_length, embed_dim]
        x = self.transformer_encoder(x)  # [batch_size, seq_length, embed_dim]
        x = self.output_linear(x)  # [batch_size, seq_length, embed_dim]
        x = self.activation(x)
        x = self.layer_norm(x[:, -1, :])  # LayerNorm 적용

        return x

# 다중 종목 주식 트레이딩 환경 정의
class MultiStockTradingEnv(gym.Env):
    def __init__(self, dfs, stock_dim=3, initial_balance=5000000, max_stock=500, seq_length=20):
        super(MultiStockTradingEnv, self).__init__()
        self.dfs = dfs  # 종목별 데이터프레임 딕셔너리
        self.stock_dim = stock_dim  # 종목 수
        self.initial_balance = initial_balance  # 초기 자본금 증가
        self.max_stock = max_stock  # 각 종목당 최대 보유 주식 수 증가
        self.transaction_fee = 0.0025  # 거래 수수료 0.25%
        self.slippage = 0.0005  # 슬리피지 0.3%
        self.max_loss = 0.05  # 최대 허용 손실 (20%)
        self.seq_length = seq_length  # 시퀀스 길이

        # 상태 공간: 시퀀스 길이에 따른 각 종목의 [Close, MA10, MA20, RSI, Volume, Bollinger Bands]와 보유 주식 수
        # 각 종목: (7 * seq_length) + 1 (보유 주식 수)
        # 총: stock_dim * (7 * seq_length +1) + 1 (balance)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.stock_dim * (7 * self.seq_length + 1) + 1,), dtype=np.float32
        )
        self.action_space = spaces.MultiDiscrete([11] * self.stock_dim)  # 각 종목별로 11개의 액션

        # 초기화
        self.reset()

    def reset(self):
        self.balance = self.initial_balance
        self.portfolio_value = self.initial_balance
        self.current_step = 0
        self.stock_owned = {ticker: {'quantity': 0, 'avg_price': 0} for ticker in self.dfs.keys()}
        self.stock_price = {}
        self.total_asset = []

        # 히스토리 초기화
        self.balance_history = [self.balance]
        self.portfolio_value_history = [self.portfolio_value]
        self.action_history = []
        self.price_history = {ticker: [] for ticker in self.dfs.keys()}
        self.trade_history = []  # 매수/매도 내역 저장

        # 각 종목의 최대 스텝 수 계산
        self.max_steps = min(len(df) for df in self.dfs.values()) - self.seq_length - 1
        if self.max_steps <= 0:
            raise ValueError("데이터프레임의 길이가 시퀀스 길이보다 짧습니다.")

        # 각 종목의 현재 인덱스 초기화
        self.data_indices = {ticker: self.seq_length for ticker in self.dfs.keys()}  # 시퀀스 길이만큼 초기 인덱스

        return self._next_observation()

    def _next_observation(self):
        obs = []
        for ticker, df in self.dfs.items():
            idx = self.data_indices[ticker]
            if idx < self.seq_length:
                # 충분한 시퀀스가 없으면 제로 패딩
                seq = df.loc[:idx, ['Close', 'MA10', 'MA20', 'RSI', 'Volume', 'Upper_Band', 'Lower_Band']].values
                pad_length = self.seq_length - seq.shape[0]
                if pad_length > 0:
                    pad = np.zeros((pad_length, 7))
                    seq = np.vstack((pad, seq))
            else:
                # 시퀀스 슬라이싱
                seq = df.loc[idx - self.seq_length:idx - 1, ['Close', 'MA10', 'MA20', 'RSI', 'Volume', 'Upper_Band', 'Lower_Band']].values
            obs.extend(seq.flatten())  # [seq_length * 7]
            obs.append(self.stock_owned[ticker]['quantity'])  # [1]

            # 현재 가격 저장 (iloc 사용)
            self.stock_price[ticker] = df.iloc[idx]['Close_unscaled']

        # 잔고 추가
        obs.append(self.balance)  # [1]

        return np.array(obs, dtype=np.float32)

    def step(self, actions):
        done = False
        total_reward = 0
        invalid_action_penalty = -10  # 불가능한 행동에 대한 페널티
        self.action_history.append(actions)
        trade_info = []  # 현재 스텝의 거래 내역

        prev_portfolio_value = self.portfolio_value  # 이전 포트폴리오 가치 저장

        # 액션 맵핑 정의
        action_mapping = {
            0: ('sell', 1.0),
            1: ('sell', 0.75),
            2: ('sell', 0.5),
            3: ('sell', 0.25),
            4: ('hold', 0.0),
            5: ('buy', 0.25),
            6: ('buy', 0.5),
            7: ('buy', 0.75),
            8: ('buy', 1.0)
        }

        # 종목별로 행동 수행
        for i, (ticker, df) in enumerate(self.dfs.items()):
            action = actions[i]
            idx = self.data_indices[ticker]

            # 인덱스가 데이터프레임의 범위를 벗어나면 에피소드를 종료
            if idx >= len(df):
                done = True
                trade_info.append(f"Ticker {ticker} reached end of data. Ending episode.")
                break

            actual_price = df.iloc[idx]['Close_unscaled']

            # 액션 맵핑을 통해 행동 타입과 비율 얻기
            action_type, proportion = action_mapping.get(action, ('hold', 0.0))

            # 슬리피지 적용
            if action_type == 'buy':
                adjusted_price = actual_price * (1 + self.slippage)
            elif action_type == 'sell':
                adjusted_price = actual_price * (1 - self.slippage)
            else:
                adjusted_price = actual_price

            # 거래 수수료 계산
            fee = adjusted_price * self.transaction_fee

            # buy_amount과 sell_amount 초기화
            buy_amount = 0
            sell_amount = 0

            # 행동에 따른 포트폴리오 업데이트 및 보상 계산
            reward = 0  # 각 종목별 보상 초기화
            if action_type == 'sell':
                if self.stock_owned[ticker]['quantity'] > 0:
                    sell_amount = int(self.stock_owned[ticker]['quantity'] * proportion)
                    sell_amount = max(1, sell_amount)  # 최소 1주 매도
                    sell_amount = min(sell_amount, self.stock_owned[ticker]['quantity'])  # 보유 주식 수 초과 방지
                    proceeds = adjusted_price * sell_amount - fee * sell_amount
                    self.balance += proceeds
                    # 이익 또는 손실 계산
                    profit = (adjusted_price - self.stock_owned[ticker]['avg_price']) * sell_amount - fee * sell_amount
                    reward = profit  # 매도 시 보상은 이익 또는 손실
                    self.stock_owned[ticker]['quantity'] -= sell_amount
                    if self.stock_owned[ticker]['quantity'] == 0:
                        self.stock_owned[ticker]['avg_price'] = 0
                    trade_info.append(f"Sell {sell_amount} of {ticker} at {adjusted_price:.2f}")
                else:
                    # 보유한 주식이 없으면 페널티 부여
                    reward = invalid_action_penalty
                    trade_info.append(f"Cannot Sell {ticker} (No holdings)")
            elif action_type == 'buy':
                max_can_buy = min(
                    self.max_stock - self.stock_owned[ticker]['quantity'],
                    int(self.balance // (adjusted_price + fee))
                )
                buy_amount = int(max_can_buy * proportion)
                buy_amount = max(1, buy_amount)  # 최소 1주 매수
                buy_amount = min(buy_amount, self.max_stock - self.stock_owned[ticker]['quantity'], 
                                 int(self.balance // (adjusted_price + fee)))
                if buy_amount > 0:
                    cost = adjusted_price * buy_amount + fee * buy_amount
                    self.balance -= cost
                    # 평균 매수가격 업데이트
                    total_quantity = self.stock_owned[ticker]['quantity'] + buy_amount
                    if total_quantity > 0:
                        self.stock_owned[ticker]['avg_price'] = (
                            (self.stock_owned[ticker]['avg_price'] * self.stock_owned[ticker]['quantity'] + adjusted_price * buy_amount)
                            / total_quantity
                        )
                    self.stock_owned[ticker]['quantity'] = total_quantity
                    reward = 0  # 매수 시 보상 없음
                    trade_info.append(f"Buy {buy_amount} of {ticker} at {adjusted_price:.2f}")
                else:
                    reward = invalid_action_penalty  # 매수 불가 시 페널티
                    trade_info.append(f"Cannot Buy {ticker} (Insufficient balance or max stock)")
            else:
                trade_info.append(f"Hold {ticker}")
                

            # 보상 누적
            total_reward += reward

            # 가격 히스토리 업데이트
            self.price_history[ticker].append(actual_price)

            # 다음 인덱스로 이동
            self.data_indices[ticker] += 1

            # 디버깅을 위한 로그 출력
            print(f"Ticker: {ticker}, Action: {action_type}, Proportion: {proportion}, "
                  f"Buy/Sell Amount: {buy_amount if action_type == 'buy' else sell_amount if action_type == 'sell' else 0}, "
                  f"Balance: {self.balance:.2f}, Holdings: {self.stock_owned[ticker]['quantity']}")

            # 잔고와 보유 주식 수량이 음수가 되지 않도록 방지
            if self.balance < 0:
                print(f"Warning: Balance for {ticker} is negative! Setting to 0.")
                self.balance = 0
            if self.stock_owned[ticker]['quantity'] < 0:
                print(f"Warning: Holdings for {ticker} are negative! Setting to 0.")
                self.stock_owned[ticker]['quantity'] = 0
                self.stock_owned[ticker]['avg_price'] = 0

        # 현재 스텝의 거래 내역 저장 및 출력
        if trade_info:
            print(f"Episode {self.current_step} Step {self.current_step}:")
            for info in trade_info:
                print(info)
            print()

        self.trade_history.append(trade_info)

        # 현재 포트폴리오 가치 계산
        self.portfolio_value = self.balance + sum(
            self.stock_owned[ticker]['quantity'] * self.stock_price[ticker] for ticker in self.dfs.keys()
        )
        self.total_asset.append(self.portfolio_value)

        # 보상은 포트폴리오 가치의 비율적 변화량을 사용
        if prev_portfolio_value > 0:
            portfolio_return = (self.portfolio_value - prev_portfolio_value) / prev_portfolio_value  # 비율적 변화
        else:
            portfolio_return = 0  # 이전 포트폴리오 가치가 0일 경우

        # 보상 함수 개선: 수익률에 따라 보상을 증가
        if portfolio_return > 0.01:
            scaled_reward = portfolio_return * 150  # 일정 수익률 이상일 때 보상 증가
        else:
            scaled_reward = portfolio_return * 100

        total_reward += scaled_reward  # 전체 보상에 추가

        # 포트폴리오 가치가 음수가 되지 않도록 보장
        if self.portfolio_value < 0:
            print(f"Error: Portfolio value is negative! Setting to 0.")
            self.portfolio_value = 0
            self.balance = 0  # 잔고도 0으로 설정
            done = True  # 에피소드를 종료

        # 최대 허용 손실 초과 시 종료
        if self.portfolio_value < self.initial_balance * (1 - self.max_loss):
            done = True

        # 최대 스텝 수 초과 시 종료
        self.current_step += 1
        if self.current_step >= self.max_steps:
            done = True

        # 히스토리 업데이트
        self.balance_history.append(self.balance)
        self.portfolio_value_history.append(self.portfolio_value)

        obs = self._next_observation()
        return obs, total_reward, done, {}

# PPO를 위한 액터-크리틱 신경망 정의
class ActorCritic(nn.Module):
    def __init__(self, input_dim, action_dim_list, seq_length=20):
        super(ActorCritic, self).__init__()
        self.seq_length = seq_length
        self.timesnet = TimesNet(input_dim=7, seq_length=seq_length).to(device)  # input_dim=7 (Close, MA10, MA20, RSI, Volume, Bollinger Bands)
        self.policy_head = nn.ModuleList([nn.Linear(self.timesnet.embed_dim, action_dim) for action_dim in action_dim_list])
        self.value_head = nn.Linear(self.timesnet.embed_dim * len(action_dim_list), 1)  # embed_dim * stock_dim
        self.apply(self._weights_init)  # 가중치 초기화

    def _weights_init(self, m):
        if isinstance(m, nn.Linear):
            # 정책 헤드의 바이어스를 0으로 초기화하여 행동 확률 균등화
            nn.init.zeros_(m.bias)
            nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        """
        x: [batch_size, stock_dim * (7 * seq_length +1) +1]
        """
        stock_embeds = []
        for i in range(len(tickers)):
            # 각 종목의 시퀀스 데이터: [batch_size, 7 * seq_length]
            start = i * (7 * self.seq_length + 1)
            end = start + 7 * self.seq_length
            seq = x[:, start:end]
            # Reshape to [batch_size, seq_length, 7]
            seq = seq.view(-1, self.seq_length, 7)
            embed = self.timesnet(seq)  # [batch_size, embed_dim]
            stock_embeds.append(embed)
        # 정책 헤드는 각 embed를 처리하여 policy logits을 생성
        policy_logits = [head(embed) for embed, head in zip(stock_embeds, self.policy_head)]  # [batch_size, 9] * stock_dim
        # 가치 함수는 모든 embed를 합쳐 처리
        combined_embeds = torch.cat(stock_embeds, dim=1)  # [batch_size, embed_dim * stock_dim]
        value = self.value_head(combined_embeds)  # [batch_size, 1]
        return policy_logits, value

    def act(self, state):
        state = state.to(device)
        policy_logits, _ = self.forward(state)
        actions = []
        action_logprobs = []
        for logits in policy_logits:
            dist = Categorical(logits=logits)
            action = dist.sample()
            actions.append(action.item())
            action_logprob = dist.log_prob(action)
            action_logprobs.append(action_logprob)
        return np.array(actions), torch.stack(action_logprobs)

    def evaluate(self, state, actions):
        policy_logits, value = self.forward(state)
        action_logprobs = []
        dist_entropies = []
        for i, logits in enumerate(policy_logits):
            dist = Categorical(logits=logits)
            action_logprob = dist.log_prob(actions[:, i])
            dist_entropy = dist.entropy()
            action_logprobs.append(action_logprob)
            dist_entropies.append(dist_entropy)
        return torch.stack(action_logprobs, dim=1), value.squeeze(-1), torch.stack(dist_entropies, dim=1)

# 메모리 클래스 정의
class Memory:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []

    def clear(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []

# PPO 트레이너 클래스 정의
class PPOTrainer:
    def __init__(self, env, policy, memory, optimizer, gamma=0.99, epsilon=0.2, epochs=10, entropy_coef=0.05):
        self.env = env
        self.policy = policy
        self.memory = memory
        self.optimizer = optimizer
        self.gamma = gamma
        self.epsilon = epsilon
        self.epochs = epochs
        self.entropy_coef = entropy_coef

    def train(self, max_episodes):
        for episode in range(max_episodes):
            state = self.env.reset()
            done = False
            total_reward = 0

            while not done:
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                actions, action_logprobs = self.policy.act(state_tensor)
                next_state, reward, done, _ = self.env.step(actions)
                total_reward += reward
                self.memory.states.append(state)
                self.memory.actions.append(actions)
                self.memory.logprobs.append(action_logprobs.sum().item())
                self.memory.rewards.append(reward)
                self.memory.is_terminals.append(done)
                state = next_state

            # 에피소드가 끝나면 PPO 업데이트
            self.ppo_update()
            self.memory.clear()

            # 결과 출력 및 시각화
            self.plot_results(episode, total_reward)

    def ppo_update(self):
        if len(self.memory.states) == 0:
            return

        # 메모리에서 텐서로 변환
        states = torch.tensor(self.memory.states, dtype=torch.float32).to(device)
        actions = torch.tensor(self.memory.actions, dtype=torch.int64).to(device)
        old_logprobs = torch.tensor(self.memory.logprobs, dtype=torch.float32).to(device)
        rewards = self.memory.rewards
        is_terminals = self.memory.is_terminals

        # 리턴 계산
        returns = self.compute_returns(rewards, is_terminals)

        # 어드밴티지 계산
        advantages = self.compute_advantages(states, returns)

        # 정책 업데이트
        for epoch in range(self.epochs):
            action_logprobs, state_values, dist_entropies = self.policy.evaluate(states, actions)
            total_logprobs = action_logprobs.sum(dim=1)
            total_entropies = dist_entropies.sum(dim=1)
            ratios = torch.exp(total_logprobs - old_logprobs)
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1 - self.epsilon, 1 + self.epsilon) * advantages
            value_loss = F.mse_loss(state_values.squeeze(-1), returns)
            loss = -torch.min(surr1, surr2) + 0.5 * value_loss - self.entropy_coef * total_entropies

            self.optimizer.zero_grad()
            loss_mean = loss.mean()
            loss_mean.backward()
            torch.nn.utils.clip_grad_norm_(self.policy.parameters(), max_norm=0.5)
            self.optimizer.step()

            print(f"Epoch {epoch+1}, Loss: {loss_mean.item():.4f}")

    def compute_returns(self, rewards, is_terminals):
        returns = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(rewards), reversed(is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            returns.insert(0, discounted_reward)
        return torch.tensor(returns, dtype=torch.float32).to(device)

    def compute_advantages(self, states, returns):
        with torch.no_grad():
            _, state_values = self.policy.forward(states)
            advantages = returns - state_values.squeeze(-1)
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        return advantages

    def plot_results(self, episode, total_reward):
        # 행동 분포 및 결과 시각화
        action_counts = np.zeros(9)
        for actions in self.env.action_history:
            action_counts += np.bincount(actions, minlength=9)

        plt.figure(figsize=(18, 12))
        plt.subplot(4, 1, 1)
        plt.plot(self.env.portfolio_value_history)
        plt.title(f'Episode {episode+1} - Portfolio Value Over Time')
        plt.ylabel('Portfolio Value')

        plt.subplot(4, 1, 2)
        action_labels = ['Sell 100%', 'Sell 75%', 'Sell 50%', 'Sell 25%', 'Hold', 
                        'Buy 25%', 'Buy 50%', 'Buy 75%', 'Buy 100%']
        plt.bar(action_labels, action_counts, color=['red', 'darkred', 'orange', 'lightcoral', 'gray', 
                                                    'lightgreen', 'green', 'darkgreen', 'lime'])
        plt.title('Action Distribution')
        plt.ylabel('Counts')
        plt.xticks(rotation=45)

        plt.subplot(4, 1, 3)
        initial_prices = {ticker: self.env.price_history[ticker][0] for ticker in tickers}
        final_prices = {ticker: self.env.price_history[ticker][-1] for ticker in tickers}
        returns = []
        for ticker in tickers:
            if initial_prices[ticker] == 0:
                ret = 0
            else:
                ret = (final_prices[ticker] - initial_prices[ticker]) / initial_prices[ticker] * 100
            returns.append(ret)
        plt.bar(tickers, returns, color=['blue', 'orange', 'purple'])
        plt.title('Stock Returns (%)')
        plt.ylabel('Return (%)')

        plt.subplot(4, 1, 4)
        hold_counts = [self.env.stock_owned[ticker]['quantity'] for ticker in tickers]
        plt.bar(tickers, hold_counts, color=['cyan', 'magenta', 'yellow'])
        plt.title('Current Holdings')
        plt.ylabel('Number of Stocks')

        plt.tight_layout()
        plt.show()

        print(f"Episode {episode+1} completed. Total Reward: {total_reward:.2f}, Final Portfolio Value: {self.env.portfolio_value_history[-1]:.2f}")
        print(f"Action counts:")
        for i, label in enumerate(action_labels):
            print(f"  {label}: {int(action_counts[i])}")
        print('-' * 50)

# 데이터 로드 및 환경 설정
tickers = ['AAPL', 'MSFT', 'GOOGL']
dfs = {}

# 데이터 로드 및 기술적 지표 계산
for ticker in tickers:
    df = yf.download(ticker, start='2019-01-01', end='2023-12-31', progress=False)  # 데이터 기간을 5년으로 확장
    # 원래의 Close 가격 보존
    df.loc[:, 'Close_unscaled'] = df['Close']  # 실제 가격 저장

    # 기술적 지표 계산
    df.loc[:, 'MA10'] = df['Close'].rolling(window=10).mean()
    df.loc[:, 'MA20'] = df['Close'].rolling(window=20).mean()

    # 볼린저 밴드 계산 (20일 이동평균 ± 2표준편차)
    df.loc[:, 'Upper_Band'] = df['MA20'] + 2 * df['Close'].rolling(window=20).std()
    df.loc[:, 'Lower_Band'] = df['MA20'] - 2 * df['Close'].rolling(window=20).std()

    # RSI 계산
    delta = df['Close'].diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ema_up = up.ewm(com=13, adjust=False).mean()
    ema_down = down.ewm(com=13, adjust=False).mean()
    rs = ema_up / ema_down
    df.loc[:, 'RSI'] = 100 - (100 / (1 + rs))

    df = df.dropna().copy()  # 복사하여 경고 방지

    # 입력 데이터 정규화 (거래량과 볼린저밴드 포함)
    scaler = StandardScaler()
    feature_cols = ['Close', 'MA10', 'MA20', 'RSI', 'Volume', 'Upper_Band', 'Lower_Band']
    df.loc[:, feature_cols] = scaler.fit_transform(df[feature_cols])

    dfs[ticker] = df.reset_index(drop=True)

# 환경 생성
env = MultiStockTradingEnv(dfs, initial_balance=5000000, seq_length=20)

# PPO 모델, 옵티마이저 및 메모리 초기화
policy = ActorCritic(env.observation_space.shape[0], [9] * env.stock_dim, seq_length=env.seq_length).to(device)
optimizer = optim.Adam(policy.parameters(), lr=1e-5)  # 학습률 감소
memory = Memory()

# 트레이너 생성
trainer = PPOTrainer(env, policy, memory, optimizer, gamma=0.75, epsilon=0.4, epochs=10)

# 학습 시작
trainer.train(max_episodes=100)
# Out:
# Using device: cuda
# C:\Users\G013\AppData\Local\Temp\ipykernel_764\540126853.py:558: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 2.76031244  1.19445648  0.5740008  ... -1.01306934 -1.28284054
#  -1.11797567]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, feature_cols] = scaler.fit_transform(df[feature_cols])
# C:\Users\G013\AppData\Local\Temp\ipykernel_764\540126853.py:558: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.61473162  2.11058568  0.49374511 ... -1.16569491 -1.21221969
#  -0.85861851]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, feature_cols] = scaler.fit_transform(df[feature_cols])
# C:\Users\G013\AppData\Local\Temp\ipykernel_764\540126853.py:558: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.27933852  0.43632012 -0.03609425 ... -0.93149074 -1.16935097
#  -0.99133255]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, feature_cols] = scaler.fit_transform(df[feature_cols])
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4983718.47, Holdings: 375
# Ticker: MSFT, Action: buy, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4927535.35, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4913411.22, Holdings: 250
# Episode 0 Step 0:
# Buy 375 of AAPL at 43.31
# Buy 500 of MSFT at 112.09
# Buy 250 of GOOGL at 56.36
#
# Ticker: AAPL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 125, Balance: 4907926.99, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4907926.99, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 0.25, Buy/Sell Amount: 62, Balance: 4911476.73, Holdings: 188
# Episode 1 Step 1:
# Buy 125 of AAPL at 43.76
# Cannot Buy MSFT (Insufficient balance or max stock)
# Sell 62 of GOOGL at 57.40
#
# Ticker: AAPL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4911476.73, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4939457.57, Holdings: 250
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 188, Balance: 4950267.21, Holdings: 0
# Episode 2 Step 2:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 250 of MSFT at 112.20
# Sell 188 of GOOGL at 57.64
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4950267.21, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4936262.80, Holdings: 375
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4921604.06, Holdings: 250
# Episode 3 Step 3:
# Hold AAPL
# Buy 125 of MSFT at 111.76
# Buy 250 of GOOGL at 58.49
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4921604.06, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4911180.12, Holdings: 468
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4903877.39, Holdings: 375
# Episode 4 Step 4:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 93 of MSFT at 111.81
# Buy 125 of GOOGL at 58.28
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4903877.39, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 16, Balance: 4902105.85, Holdings: 484
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4896738.34, Holdings: 468
# Episode 5 Step 5:
# Hold AAPL
# Buy 16 of MSFT at 110.45
# Buy 93 of GOOGL at 57.57
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4896738.34, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.25, Buy/Sell Amount: 121, Balance: 4910069.95, Holdings: 363
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 468, Balance: 4936898.56, Holdings: 0
# Episode 6 Step 6:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 121 of MSFT at 110.45
# Sell 468 of GOOGL at 57.47
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4936898.56, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 68, Balance: 4929203.09, Holdings: 431
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4914418.10, Holdings: 250
# Episode 7 Step 7:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 68 of MSFT at 112.89
# Buy 250 of GOOGL at 58.99
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4914418.10, Holdings: 500
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4914418.10, Holdings: 431
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 250, Balance: 4929338.84, Holdings: 0
# Episode 8 Step 8:
# Hold AAPL
# Hold MSFT
# Sell 250 of GOOGL at 59.83
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4929338.84, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 34, Balance: 4925434.16, Holdings: 465
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4910400.93, Holdings: 250
# Episode 9 Step 9:
# Hold AAPL
# Buy 34 of MSFT at 114.56
# Buy 250 of GOOGL at 59.98
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4910400.93, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 17, Balance: 4908447.05, Holdings: 482
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 187, Balance: 4919563.77, Holdings: 63
# Episode 10 Step 10:
# Hold AAPL
# Buy 17 of MSFT at 114.65
# Sell 187 of GOOGL at 59.60
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4919563.77, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 241, Balance: 4947414.31, Holdings: 241
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 218, Balance: 4934401.10, Holdings: 281
# Episode 11 Step 11:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 241 of MSFT at 115.85
# Buy 218 of GOOGL at 59.54
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4934401.10, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 129, Balance: 4919189.06, Holdings: 370
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 140, Balance: 4927483.96, Holdings: 141
# Episode 12 Step 12:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 129 of MSFT at 117.63
# Sell 140 of GOOGL at 59.40
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4927483.96, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 65, Balance: 4919813.76, Holdings: 435
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 141, Balance: 4928265.68, Holdings: 0
# Episode 13 Step 13:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 65 of MSFT at 117.71
# Sell 141 of GOOGL at 60.09
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4928265.68, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 217, Balance: 4953691.04, Holdings: 218
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4953691.04, Holdings: 0
# Episode 14 Step 14:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 217 of MSFT at 117.46
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4953691.04, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 211, Balance: 4928248.49, Holdings: 429
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4928248.49, Holdings: 0
# Episode 15 Step 15:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 211 of MSFT at 120.28
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4928248.49, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 35, Balance: 4924139.45, Holdings: 464
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4924139.45, Holdings: 0
# Episode 16 Step 16:
# Hold AAPL
# Buy 35 of MSFT at 117.11
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4924139.45, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 18, Balance: 4922015.21, Holdings: 482
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4914509.12, Holdings: 125
# Episode 17 Step 17:
# Hold AAPL
# Buy 18 of MSFT at 117.72
# Buy 125 of GOOGL at 59.90
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4914509.12, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 1.0, Buy/Sell Amount: 18, Balance: 4912380.37, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 93, Balance: 4906831.01, Holdings: 218
# Episode 18 Step 18:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 18 of MSFT at 117.97
# Buy 93 of GOOGL at 59.52
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4906831.01, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4906831.01, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 218, Balance: 4919632.82, Holdings: 0
# Episode 19 Step 19:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Cannot Buy MSFT (Insufficient balance or max stock)
# Sell 218 of GOOGL at 58.87
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4919632.82, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4934205.24, Holdings: 375
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4919507.88, Holdings: 250
# Episode 20 Step 20:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 125 of MSFT at 116.87
# Buy 250 of GOOGL at 58.64
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4919507.88, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4908506.54, Holdings: 468
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4901128.91, Holdings: 375
# Episode 21 Step 21:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 93 of MSFT at 118.00
# Buy 125 of GOOGL at 58.87
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4901128.91, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 16, Balance: 4899218.87, Holdings: 484
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 375, Balance: 4921632.33, Holdings: 0
# Episode 22 Step 22:
# Hold AAPL
# Buy 16 of MSFT at 119.08
# Sell 375 of GOOGL at 59.92
#
# Ticker: AAPL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4945812.11, Holdings: 0
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 8, Balance: 4944855.72, Holdings: 492
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4937298.49, Holdings: 125
# Episode 23 Step 23:
# Sell 500 of AAPL at 48.48
# Buy 8 of MSFT at 119.25
# Buy 125 of GOOGL at 60.31
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4931175.48, Holdings: 125
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4931175.48, Holdings: 492
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 62, Balance: 4934917.73, Holdings: 63
# Episode 24 Step 24:
# Buy 125 of AAPL at 48.86
# Hold MSFT
# Sell 62 of GOOGL at 60.51
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 187, Balance: 4925741.77, Holdings: 312
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 6, Balance: 4925023.46, Holdings: 498
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 109, Balance: 4918357.51, Holdings: 172
# Episode 25 Step 25:
# Buy 187 of AAPL at 48.95
# Buy 6 of MSFT at 119.42
# Buy 109 of GOOGL at 61.00
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 94, Balance: 4913714.11, Holdings: 406
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 373, Balance: 4958298.98, Holdings: 125
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 129, Balance: 4966089.40, Holdings: 43
# Episode 26 Step 26:
# Buy 94 of AAPL at 49.27
# Sell 373 of MSFT at 119.83
# Sell 129 of GOOGL at 60.54
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 23, Balance: 4964935.38, Holdings: 429
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4976055.42, Holdings: 32
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 342, Balance: 4955331.82, Holdings: 385
# Episode 27 Step 27:
# Buy 23 of AAPL at 50.05
# Sell 93 of MSFT at 119.87
# Buy 342 of GOOGL at 60.44
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4955331.82, Holdings: 429
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 234, Balance: 4927336.53, Holdings: 266
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 385, Balance: 4950418.89, Holdings: 0
# Episode 28 Step 28:
# Hold AAPL
# Buy 234 of MSFT at 119.34
# Sell 385 of GOOGL at 60.10
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 35, Balance: 4948658.19, Holdings: 464
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 117, Balance: 4934553.76, Holdings: 383
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4934553.76, Holdings: 0
# Episode 29 Step 29:
# Buy 35 of AAPL at 50.18
# Buy 117 of MSFT at 120.25
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4934553.76, Holdings: 464
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 58, Balance: 4927553.67, Holdings: 441
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4927553.67, Holdings: 0
# Episode 30 Step 30:
# Hold AAPL
# Buy 58 of MSFT at 120.39
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 18, Balance: 4926656.07, Holdings: 482
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 29, Balance: 4923137.99, Holdings: 470
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4923137.99, Holdings: 0
# Episode 31 Step 31:
# Buy 18 of AAPL at 49.74
# Buy 29 of MSFT at 121.01
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4923137.99, Holdings: 482
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 352, Balance: 4965619.82, Holdings: 118
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4965619.82, Holdings: 0
# Episode 32 Step 32:
# Hold AAPL
# Sell 352 of MSFT at 120.99
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4965619.82, Holdings: 482
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 191, Balance: 4942483.52, Holdings: 309
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4942483.52, Holdings: 0
# Episode 33 Step 33:
# Hold AAPL
# Buy 191 of MSFT at 120.83
# Hold GOOGL
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 9, Balance: 4942025.11, Holdings: 491
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 95, Balance: 4930422.24, Holdings: 404
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4930422.24, Holdings: 0
# Episode 34 Step 34:
# Buy 9 of AAPL at 50.81
# Buy 95 of MSFT at 121.83
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4930422.24, Holdings: 491
# Ticker: MSFT, Action: sell, Proportion: 1.0, Buy/Sell Amount: 404, Balance: 4980114.26, Holdings: 0
# Ticker: GOOGL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4948984.36, Holdings: 500
# Episode 35 Step 35:
# Hold AAPL
# Sell 404 of MSFT at 123.31
# Buy 500 of GOOGL at 62.10
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4948984.36, Holdings: 491
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4917951.50, Holdings: 250
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4917951.50, Holdings: 500
# Episode 36 Step 36:
# Hold AAPL
# Buy 250 of MSFT at 123.82
# Cannot Buy GOOGL (Insufficient balance or max stock)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4917951.50, Holdings: 491
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4917951.50, Holdings: 250
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4917951.50, Holdings: 500
# Episode 37 Step 37:
# Hold AAPL
# Hold MSFT
# Cannot Buy GOOGL (Insufficient balance or max stock)
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 2, Balance: 4917847.61, Holdings: 493
# Ticker: MSFT, Action: buy, Proportion: 0.25, Buy/Sell Amount: 62, Balance: 4910073.72, Holdings: 312
# Ticker: GOOGL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4910073.72, Holdings: 500
# Episode 38 Step 38:
# Buy 2 of AAPL at 51.82
# Buy 62 of MSFT at 125.07
# Cannot Buy GOOGL (Insufficient balance or max stock)
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 246, Balance: 4922660.59, Holdings: 247
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4922660.59, Holdings: 312
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4954249.08, Holdings: 0
# Episode 39 Step 39:
# Sell 246 of AAPL at 51.29
# Hold MSFT
# Sell 500 of GOOGL at 63.34
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 126, Balance: 4947794.31, Holdings: 373
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 94, Balance: 4935548.01, Holdings: 406
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4927540.17, Holdings: 125
# Episode 40 Step 40:
# Buy 126 of AAPL at 51.10
# Buy 94 of MSFT at 129.95
# Buy 125 of GOOGL at 63.90
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4927540.17, Holdings: 373
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 47, Balance: 4921422.68, Holdings: 453
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 125, Balance: 4929499.63, Holdings: 0
# Episode 41 Step 41:
# Hold AAPL
# Buy 47 of MSFT at 129.83
# Sell 125 of GOOGL at 64.78
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4929499.63, Holdings: 373
# Ticker: MSFT, Action: buy, Proportion: 1.0, Buy/Sell Amount: 47, Balance: 4923343.01, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4900795.04, Holdings: 375
# Episode 42 Step 42:
# Hold AAPL
# Buy 47 of MSFT at 130.67
# Buy 375 of GOOGL at 59.98
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4900795.04, Holdings: 373
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4948606.23, Holdings: 125
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 375, Balance: 4970540.01, Holdings: 0
# Episode 43 Step 43:
# Hold AAPL
# Sell 375 of MSFT at 127.82
# Sell 375 of GOOGL at 58.64
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 63, Balance: 4967236.01, Holdings: 436
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 187, Balance: 4943563.91, Holdings: 312
# Ticker: GOOGL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4914313.63, Holdings: 500
# Episode 44 Step 44:
# Buy 63 of AAPL at 52.31
# Buy 187 of MSFT at 126.27
# Buy 500 of GOOGL at 58.35
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 32, Balance: 4912614.55, Holdings: 468
# Ticker: MSFT, Action: sell, Proportion: 0.25, Buy/Sell Amount: 78, Balance: 4922638.60, Holdings: 234
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4952288.17, Holdings: 0
# Episode 45 Step 45:
# Buy 32 of AAPL at 52.96
# Sell 78 of MSFT at 128.84
# Sell 500 of GOOGL at 59.45
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 16, Balance: 4951451.75, Holdings: 484
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 133, Balance: 4934356.65, Holdings: 367
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4934356.65, Holdings: 0
# Episode 46 Step 46:
# Buy 16 of AAPL at 52.15
# Buy 133 of MSFT at 128.21
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4934356.65, Holdings: 484
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 66, Balance: 4926047.46, Holdings: 433
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4926047.46, Holdings: 0
# Episode 47 Step 47:
# Hold AAPL
# Buy 66 of MSFT at 125.58
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 8, Balance: 4925640.44, Holdings: 492
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 33, Balance: 4921486.18, Holdings: 466
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4921486.18, Holdings: 0
# Episode 48 Step 48:
# Buy 8 of AAPL at 50.75
# Buy 33 of MSFT at 125.57
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 2, Balance: 4921385.52, Holdings: 494
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 17, Balance: 4919245.62, Holdings: 483
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4919245.62, Holdings: 0
# Episode 49 Step 49:
# Buy 2 of AAPL at 50.21
# Buy 17 of MSFT at 125.56
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 370, Balance: 4937430.07, Holdings: 124
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 8, Balance: 4936409.98, Holdings: 491
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4936409.98, Holdings: 0
# Episode 50 Step 50:
# Sell 370 of AAPL at 49.27
# Buy 8 of MSFT at 127.19
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 188, Balance: 4927654.94, Holdings: 312
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 4, Balance: 4927160.06, Holdings: 495
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4927160.06, Holdings: 0
# Episode 51 Step 51:
# Buy 188 of AAPL at 46.45
# Buy 4 of MSFT at 123.41
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4927160.06, Holdings: 312
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 371, Balance: 4973296.13, Holdings: 124
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4959193.18, Holdings: 250
# Episode 52 Step 52:
# Hold AAPL
# Sell 371 of MSFT at 124.67
# Buy 250 of GOOGL at 56.27
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4959193.18, Holdings: 312
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 188, Balance: 4935430.31, Holdings: 312
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4935430.31, Holdings: 250
# Episode 53 Step 53:
# Hold AAPL
# Buy 188 of MSFT at 126.08
# Hold GOOGL
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 156, Balance: 4942821.20, Holdings: 156
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 94, Balance: 4930665.41, Holdings: 406
# Ticker: GOOGL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 187, Balance: 4941707.27, Holdings: 63
# Episode 54 Step 54:
# Sell 156 of AAPL at 47.50
# Buy 94 of MSFT at 128.99
# Sell 187 of GOOGL at 59.20
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4941707.27, Holdings: 156
# Ticker: MSFT, Action: sell, Proportion: 0.25, Buy/Sell Amount: 101, Balance: 4954603.56, Holdings: 305
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 63, Balance: 4958274.17, Holdings: 0
# Episode 55 Step 55:
# Hold AAPL
# Sell 101 of MSFT at 128.01
# Sell 63 of GOOGL at 58.41
#
# Ticker: AAPL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 117, Balance: 4963613.50, Holdings: 39
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 97, Balance: 4951333.41, Holdings: 402
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4944157.81, Holdings: 125
# Episode 56 Step 56:
# Sell 117 of AAPL at 45.75
# Buy 97 of MSFT at 126.28
# Buy 125 of GOOGL at 57.26
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4944157.81, Holdings: 39
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 73, Balance: 4934866.31, Holdings: 475
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 281, Balance: 4918597.75, Holdings: 406
# Episode 57 Step 57:
# Hold AAPL
# Buy 73 of MSFT at 126.96
# Buy 281 of GOOGL at 57.75
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 19, Balance: 4919463.35, Holdings: 20
# Ticker: MSFT, Action: buy, Proportion: 0.25, Buy/Sell Amount: 6, Balance: 4918695.03, Holdings: 481
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4918695.03, Holdings: 406
# Episode 58 Step 58:
# Sell 19 of AAPL at 45.67
# Buy 6 of MSFT at 127.73
# Hold GOOGL
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 240, Balance: 4907883.08, Holdings: 260
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 9, Balance: 4906744.05, Holdings: 490
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 406, Balance: 4929924.73, Holdings: 0
# Episode 59 Step 59:
# Buy 240 of AAPL at 44.94
# Buy 9 of MSFT at 126.24
# Sell 406 of GOOGL at 57.24
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4929924.73, Holdings: 260
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 5, Balance: 4929291.64, Holdings: 495
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4929291.64, Holdings: 0
# Episode 60 Step 60:
# Hold AAPL
# Buy 5 of MSFT at 126.30
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4929291.64, Holdings: 260
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 2, Balance: 4929038.56, Holdings: 497
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4907607.68, Holdings: 375
# Episode 61 Step 61:
# Hold AAPL
# Buy 2 of MSFT at 126.22
# Buy 375 of GOOGL at 57.01
#
# Ticker: AAPL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 195, Balance: 4916229.02, Holdings: 65
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 2, Balance: 4915978.39, Holdings: 499
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 375, Balance: 4936914.30, Holdings: 0
# Episode 62 Step 62:
# Sell 195 of AAPL at 44.32
# Buy 2 of MSFT at 125.00
# Sell 375 of GOOGL at 55.97
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 217, Balance: 4927212.49, Holdings: 282
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 249, Balance: 4958425.38, Holdings: 250
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4958425.38, Holdings: 0
# Episode 63 Step 63:
# Buy 217 of AAPL at 44.60
# Sell 249 of MSFT at 125.67
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 109, Balance: 4953640.41, Holdings: 391
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4953640.41, Holdings: 250
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4946704.03, Holdings: 125
# Episode 64 Step 64:
# Buy 109 of AAPL at 43.79
# Hold MSFT
# Buy 125 of GOOGL at 55.35
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4946704.03, Holdings: 391
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4931679.07, Holdings: 375
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 281, Balance: 4917040.97, Holdings: 406
# Episode 65 Step 65:
# Hold AAPL
# Buy 125 of MSFT at 119.90
# Buy 281 of GOOGL at 51.96
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4917040.97, Holdings: 391
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4905552.72, Holdings: 468
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 47, Balance: 4903067.23, Holdings: 453
# Episode 66 Step 66:
# Hold AAPL
# Buy 93 of MSFT at 123.22
# Buy 47 of GOOGL at 52.75
#
# Ticker: AAPL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 109, Balance: 4898078.08, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.25, Buy/Sell Amount: 8, Balance: 4897068.42, Holdings: 476
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 35, Balance: 4895234.82, Holdings: 488
# Episode 67 Step 67:
# Buy 109 of AAPL at 45.66
# Buy 8 of MSFT at 125.89
# Buy 35 of GOOGL at 52.26
#
# Ticker: AAPL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4895234.82, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 357, Balance: 4940729.72, Holdings: 119
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 488, Balance: 4966218.40, Holdings: 0
# Episode 68 Step 68:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 357 of MSFT at 127.76
# Sell 488 of GOOGL at 52.36
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4966218.40, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.25, Buy/Sell Amount: 95, Balance: 4953697.93, Holdings: 214
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4953697.93, Holdings: 0
# Episode 69 Step 69:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 95 of MSFT at 131.47
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4953697.93, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 143, Balance: 4934679.22, Holdings: 357
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4934679.22, Holdings: 0
# Episode 70 Step 70:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 143 of MSFT at 132.67
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4934679.22, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 267, Balance: 4969844.16, Holdings: 90
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4949513.82, Holdings: 375
# Episode 71 Step 71:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 267 of MSFT at 132.03
# Buy 375 of GOOGL at 54.08
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4949513.82, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.25, Buy/Sell Amount: 22, Balance: 4952397.93, Holdings: 68
# Ticker: GOOGL, Action: sell, Proportion: 0.25, Buy/Sell Amount: 93, Balance: 4957400.70, Holdings: 282
# Episode 72 Step 72:
# Hold AAPL
# Sell 22 of MSFT at 131.42
# Sell 93 of GOOGL at 53.93
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4969498.68, Holdings: 250
# Ticker: MSFT, Action: sell, Proportion: 1.0, Buy/Sell Amount: 68, Balance: 4978469.46, Holdings: 0
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4978469.46, Holdings: 282
# Episode 73 Step 73:
# Sell 250 of AAPL at 48.51
# Sell 68 of MSFT at 132.25
# Hold GOOGL
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 187, Balance: 4969431.82, Holdings: 437
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4919614.01, Holdings: 375
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 109, Balance: 4913675.90, Holdings: 391
# Episode 74 Step 74:
# Buy 187 of AAPL at 48.21
# Buy 375 of MSFT at 132.52
# Buy 109 of GOOGL at 54.34
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4913675.90, Holdings: 437
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 62, Balance: 4905414.48, Holdings: 437
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 27, Balance: 4903933.30, Holdings: 418
# Episode 75 Step 75:
# Hold AAPL
# Buy 62 of MSFT at 132.92
# Buy 27 of GOOGL at 54.72
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 47, Balance: 4901594.51, Holdings: 484
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 218, Balance: 4930971.04, Holdings: 219
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 41, Balance: 4928698.49, Holdings: 459
# Episode 76 Step 76:
# Buy 47 of AAPL at 49.64
# Sell 218 of MSFT at 135.09
# Buy 41 of GOOGL at 55.29
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 12, Balance: 4928103.10, Holdings: 496
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4928103.10, Holdings: 219
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 459, Balance: 4953375.59, Holdings: 0
# Episode 77 Step 77:
# Buy 12 of AAPL at 49.49
# Hold MSFT
# Sell 459 of GOOGL at 55.20
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4953375.59, Holdings: 496
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 140, Balance: 4934145.05, Holdings: 359
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4934145.05, Holdings: 0
# Episode 78 Step 78:
# Hold AAPL
# Buy 140 of MSFT at 137.02
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4934145.05, Holdings: 496
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 105, Balance: 4919720.04, Holdings: 464
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4905610.69, Holdings: 250
# Episode 79 Step 79:
# Hold AAPL
# Buy 105 of MSFT at 137.04
# Buy 250 of GOOGL at 56.30
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4905610.69, Holdings: 496
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 18, Balance: 4903123.21, Holdings: 482
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 250, Balance: 4917040.10, Holdings: 0
# Episode 80 Step 80:
# Hold AAPL
# Buy 18 of MSFT at 137.85
# Sell 250 of GOOGL at 55.81
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4917040.10, Holdings: 496
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 361, Balance: 4965063.88, Holdings: 121
# Ticker: GOOGL, Action: sell, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4965063.88, Holdings: 0
# Episode 81 Step 81:
# Hold AAPL
# Sell 361 of MSFT at 133.36
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 2, Balance: 4964963.68, Holdings: 498
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 189, Balance: 4939574.94, Holdings: 310
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4926030.42, Holdings: 250
# Episode 82 Step 82:
# Buy 2 of AAPL at 49.97
# Buy 189 of MSFT at 134.00
# Buy 250 of GOOGL at 54.04
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 1, Balance: 4925980.33, Holdings: 499
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 95, Balance: 4913197.83, Holdings: 405
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 250, Balance: 4926615.35, Holdings: 0
# Episode 83 Step 83:
# Buy 1 of AAPL at 49.96
# Buy 95 of MSFT at 134.22
# Sell 250 of GOOGL at 53.80
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 1, Balance: 4926565.72, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 71, Balance: 4917026.02, Holdings: 476
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4917026.02, Holdings: 0
# Episode 84 Step 84:
# Buy 1 of AAPL at 49.50
# Buy 71 of MSFT at 134.03
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4917026.02, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 12, Balance: 4915392.97, Holdings: 488
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4915392.97, Holdings: 0
# Episode 85 Step 85:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 12 of MSFT at 135.75
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4915392.97, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 366, Balance: 4965231.35, Holdings: 122
# Ticker: GOOGL, Action: buy, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4937332.87, Holdings: 500
# Episode 86 Step 86:
# Hold AAPL
# Sell 366 of MSFT at 136.51
# Buy 500 of GOOGL at 55.66
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4937332.87, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 91, Balance: 4949804.22, Holdings: 31
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4949804.22, Holdings: 500
# Episode 87 Step 87:
# Hold AAPL
# Sell 91 of MSFT at 137.39
# Hold GOOGL
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4949804.22, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 234, Balance: 4917635.92, Holdings: 265
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 500, Balance: 4945867.76, Holdings: 0
# Episode 88 Step 88:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 234 of MSFT at 137.13
# Sell 500 of GOOGL at 56.61
#
# Ticker: AAPL, Action: sell, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4964563.40, Holdings: 125
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 117, Balance: 4948490.99, Holdings: 382
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4934489.21, Holdings: 250
# Episode 89 Step 89:
# Sell 375 of AAPL at 49.98
# Buy 117 of MSFT at 137.03
# Buy 250 of GOOGL at 55.87
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4934489.21, Holdings: 125
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 59, Balance: 4926413.91, Holdings: 441
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4919366.01, Holdings: 375
# Episode 90 Step 90:
# Hold AAPL
# Buy 59 of MSFT at 136.53
# Buy 125 of GOOGL at 56.24
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 281, Balance: 4905046.25, Holdings: 406
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 29, Balance: 4901036.60, Holdings: 470
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 31, Balance: 4899262.89, Holdings: 406
# Episode 91 Step 91:
# Buy 281 of AAPL at 50.83
# Buy 29 of MSFT at 137.92
# Buy 31 of GOOGL at 57.07
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 47, Balance: 4896885.21, Holdings: 453
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 352, Balance: 4945455.92, Holdings: 118
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 406, Balance: 4968611.10, Holdings: 0
# Episode 92 Step 92:
# Buy 47 of AAPL at 50.46
# Sell 352 of MSFT at 138.33
# Sell 406 of GOOGL at 57.18
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 35, Balance: 4966826.88, Holdings: 488
# Ticker: MSFT, Action: buy, Proportion: 1.0, Buy/Sell Amount: 382, Balance: 4913607.84, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913607.84, Holdings: 0
# Episode 93 Step 93:
# Buy 35 of AAPL at 50.85
# Buy 382 of MSFT at 138.97
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 6, Balance: 4913299.10, Holdings: 494
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913299.10, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4898874.56, Holdings: 250
# Episode 94 Step 94:
# Buy 6 of AAPL at 51.33
# Cannot Buy MSFT (Insufficient balance or max stock)
# Buy 250 of GOOGL at 57.55
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 3, Balance: 4898720.73, Holdings: 497
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4898720.73, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 250, Balance: 4913095.74, Holdings: 0
# Episode 95 Step 95:
# Buy 3 of AAPL at 51.15
# Cannot Buy MSFT (Insufficient balance or max stock)
# Sell 250 of GOOGL at 57.64
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4913095.74, Holdings: 497
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913095.74, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913095.74, Holdings: 0
# Episode 96 Step 96:
# Hold AAPL
# Cannot Buy MSFT (Insufficient balance or max stock)
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 1, Balance: 4913044.17, Holdings: 498
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913044.17, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4905852.40, Holdings: 125
# Episode 97 Step 97:
# Buy 1 of AAPL at 51.44
# Cannot Buy MSFT (Insufficient balance or max stock)
# Buy 125 of GOOGL at 57.39
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 1, Balance: 4905801.60, Holdings: 499
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4905801.60, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 187, Balance: 4895189.86, Holdings: 312
# Episode 98 Step 98:
# Buy 1 of AAPL at 50.67
# Cannot Buy MSFT (Insufficient balance or max stock)
# Buy 187 of GOOGL at 56.61
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4895189.86, Holdings: 499
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4895189.86, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 141, Balance: 4887134.32, Holdings: 453
# Episode 99 Step 99:
# Hold AAPL
# Cannot Buy MSFT (Insufficient balance or max stock)
# Buy 141 of GOOGL at 56.99
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 1, Balance: 4887081.95, Holdings: 500
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4887081.95, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 453, Balance: 4913007.31, Holdings: 0
# Episode 100 Step 100:
# Buy 1 of AAPL at 52.24
# Hold MSFT
# Sell 453 of GOOGL at 57.37
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 0
# Episode 101 Step 101:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Cannot Buy MSFT (Insufficient balance or max stock)
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: GOOGL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 0
# Episode 102 Step 102:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Cannot Buy MSFT (Insufficient balance or max stock)
# Hold GOOGL
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 0
# Episode 103 Step 103:
# Hold AAPL
# Cannot Buy MSFT (Insufficient balance or max stock)
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913007.31, Holdings: 500
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4889652.93, Holdings: 375
# Episode 104 Step 104:
# Hold AAPL
# Cannot Buy MSFT (Insufficient balance or max stock)
# Buy 375 of GOOGL at 62.12
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4889652.93, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4942126.35, Holdings: 125
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4936399.01, Holdings: 468
# Episode 105 Step 105:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 375 of MSFT at 140.28
# Buy 93 of GOOGL at 61.43
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4936399.01, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4949034.12, Holdings: 32
# Ticker: GOOGL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 234, Balance: 4963244.32, Holdings: 234
# Episode 106 Step 106:
# Hold AAPL
# Sell 93 of MSFT at 136.20
# Sell 234 of GOOGL at 60.88
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4963244.32, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 234, Balance: 4930841.32, Holdings: 266
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 234, Balance: 4944976.63, Holdings: 0
# Episode 107 Step 107:
# Hold AAPL
# Buy 234 of MSFT at 138.13
# Sell 234 of GOOGL at 60.56
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4944976.63, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 175, Balance: 4920947.23, Holdings: 441
# Ticker: GOOGL, Action: sell, Proportion: 0.25, Buy/Sell Amount: 0, Balance: 4920947.23, Holdings: 0
# Episode 108 Step 108:
# Hold AAPL
# Buy 175 of MSFT at 136.97
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4920947.23, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 1.0, Buy/Sell Amount: 59, Balance: 4913123.43, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913123.43, Holdings: 0
# Episode 109 Step 109:
# Hold AAPL
# Buy 59 of MSFT at 132.28
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913123.43, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913123.43, Holdings: 500
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4913123.43, Holdings: 0
# Episode 110 Step 110:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Cannot Buy MSFT (Insufficient balance or max stock)
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 0, Balance: 4913123.43, Holdings: 500
# Ticker: MSFT, Action: sell, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4946842.01, Holdings: 250
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4946842.01, Holdings: 0
# Episode 111 Step 111:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Sell 250 of MSFT at 135.21
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 0, Balance: 4946842.01, Holdings: 500
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 125, Balance: 4929428.66, Holdings: 375
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 375, Balance: 4906744.72, Holdings: 375
# Episode 112 Step 112:
# Cannot Buy AAPL (Insufficient balance or max stock)
# Buy 125 of MSFT at 138.96
# Buy 375 of GOOGL at 60.34
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 250, Balance: 4919268.92, Holdings: 250
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 62, Balance: 4910705.28, Holdings: 437
# Ticker: GOOGL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 93, Balance: 4905160.30, Holdings: 468
# Episode 113 Step 113:
# Sell 250 of AAPL at 50.22
# Buy 62 of MSFT at 137.78
# Buy 93 of GOOGL at 59.47
#
# Ticker: AAPL, Action: buy, Proportion: 0.75, Buy/Sell Amount: 187, Balance: 4895759.73, Holdings: 437
# Ticker: MSFT, Action: buy, Proportion: 0.75, Buy/Sell Amount: 47, Balance: 4889358.45, Holdings: 484
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 8, Balance: 4888887.24, Holdings: 476
# Episode 114 Step 114:
# Buy 187 of AAPL at 50.15
# Buy 47 of MSFT at 135.86
# Buy 8 of GOOGL at 58.75
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4888887.24, Holdings: 437
# Ticker: MSFT, Action: sell, Proportion: 0.75, Buy/Sell Amount: 363, Balance: 4939048.17, Holdings: 121
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 6, Balance: 4938688.07, Holdings: 482
# Episode 115 Step 115:
# Hold AAPL
# Sell 363 of MSFT at 138.53
# Buy 6 of GOOGL at 59.87
#
# Ticker: AAPL, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4938688.07, Holdings: 437
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4938688.07, Holdings: 121
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 482, Balance: 4966662.36, Holdings: 0
# Episode 116 Step 116:
# Hold AAPL
# Hold MSFT
# Sell 482 of GOOGL at 58.18
#
# Ticker: AAPL, Action: sell, Proportion: 0.5, Buy/Sell Amount: 218, Balance: 4977624.22, Holdings: 219
# Ticker: MSFT, Action: buy, Proportion: 0.5, Buy/Sell Amount: 189, Balance: 4952282.87, Holdings: 310
# Ticker: GOOGL, Action: sell, Proportion: 1.0, Buy/Sell Amount: 0, Balance: 4952282.87, Holdings: 0
# Episode 117 Step 117:
# Sell 218 of AAPL at 50.41
# Buy 189 of MSFT at 133.75
# Cannot Sell GOOGL (No holdings)
#
# Ticker: AAPL, Action: buy, Proportion: 0.5, Buy/Sell Amount: 140, Balance: 4945033.68, Holdings: 359
# Ticker: MSFT, Action: hold, Proportion: 0.0, Buy/Sell Amount: 0, Balance: 4945033.68, Holdings: 310
# Ticker: GOOGL, Action: buy, Proportion: 0.25, Buy/Sell Amount: 125, Balance: 4937641.50, Holdings: 125
# Episode 118 Step 118:
# Buy 140 of AAPL at 51.65
# Hold MSFT
# Buy 125 of GOOGL at 58.99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 574
#     571 trainer = PPOTrainer(env, policy, memory, optimizer, gamma=0.75, epsilon=0.4, epochs=10)
#     573 # 학습 시작
# --> 574 trainer.train(max_episodes=100)
#
# Cell In[3], line 406, in PPOTrainer.train(self, max_episodes)
#     404 while not done:
#     405     state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
# --> 406     actions, action_logprobs = self.policy.act(state_tensor)
#     407     next_state, reward, done, _ = self.env.step(actions)
#     408     total_reward += reward
#
# Cell In[3], line 354, in ActorCritic.act(self, state)
#     352     action = dist.sample()
#     353     actions.append(action.item())
# --> 354     action_logprob = dist.log_prob(action)
#     355     action_logprobs.append(action_logprob)
#     356 return np.array(actions), torch.stack(action_logprobs)
#
# File c:\ProgramData\anaconda3\envs\final\lib\site-packages\torch\distributions\categorical.py:137, in Categorical.log_prob(self, value)
#     135 def log_prob(self, value):
#     136     if self._validate_args:
# --> 137         self._validate_sample(value)
#     138     value = value.long().unsqueeze(-1)
#     139     value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# File c:\ProgramData\anaconda3\envs\final\lib\site-packages\torch\distributions\distribution.py:311, in Distribution._validate_sample(self, value)
#     309 assert support is not None
#     310 valid = support.check(value)
# --> 311 if not valid.all():
#     312     raise ValueError(
#     313         "Expected value argument "
#     314         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     317         f"but found invalid values:\n{value}"
#     318     )
#
# KeyboardInterrupt:

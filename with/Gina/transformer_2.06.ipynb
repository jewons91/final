# %% [markdown]
# #### 스케일 위치 변경
# #### 하이퍼 파라미터 조정
# #### 다른 지표 추가

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# 데이터 로드
data = pd.read_csv('./000660.csv')

# 데이터 칼럼명 변경
data = data.rename(
    columns={
        '시가': 'Open',
        '고가': 'High',
        '저가': 'Low',
        '종가': 'Close',
        '거래량': 'Total_Volume',
        '매도량': 'Sell_Volume',
        '매수량': 'Buy_Volume'
    })

# %%
# 결측치 제거
data = data.dropna()

# %%
# 특성 선택
price_features = ['Open', 'High', 'Low', 'Close']
volume_features = ['Buy_Volume', 'Sell_Volume', 'Total_Volume']
features = price_features + volume_features

# %%
# 거래량 강도 계산
data['Volume_Intensity'] = data['Buy_Volume'] - data['Sell_Volume']
data['Volume_Intensity_Ratio'] = data['Volume_Intensity'] / (data['Total_Volume'] + 1e-5)
data['Buy_Sell_Ratio'] = data['Buy_Volume'] / (data['Sell_Volume'] + 1e-5)

# %%
# 새로운 특성들을 특성 리스트에 추가
features.extend(['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio'])

# %%
# 이동 평균선 추가
data['MA_5'] = data['Close'].rolling(window=5).mean()
data['MA_20'] = data['Close'].rolling(window=20).mean()
data['MA_60'] = data['Close'].rolling(window=60).mean()
data['MA_5_20_Diff'] = data['MA_5'] - data['MA_20']
data['MA_20_60_Diff'] = data['MA_20'] - data['MA_60']

# %%
# 추가된 특성을 특성 리스트에 포함
features.extend(['MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff'])

# %%
# 이동 평균선 계산 후 결측치 제거
data = data.dropna()

# %%
# 가격 급변 레이블링
price_threshold = 0.005  # 0.5% 이상 변동 시 급변으로 간주

data['Price_Change'] = data['Close'].pct_change()
data = data.dropna()

def label_price_change(change):
    if change >= price_threshold:
        return 2  # 상승
    elif change <= -price_threshold:
        return 0  # 하락
    else:
        return 1  # 보합

data['Price_Label'] = data['Price_Change'].apply(label_price_change)

# %%
# 결측치 제거 (최종)
data = data.dropna()

# %%
# 스케일러 딕셔너리 생성
scalers = {}

# %%
# 가격 관련 특성 스케일링
for feature in price_features + ['MA_5', 'MA_20', 'MA_60', 'MA_5_20_Diff', 'MA_20_60_Diff']:
    scaler = StandardScaler()
    data[feature] = scaler.fit_transform(data[[feature]])
    scalers[feature] = scaler

# %%
# 거래량 관련 특성 스케일링
for feature in volume_features + ['Volume_Intensity', 'Volume_Intensity_Ratio', 'Buy_Sell_Ratio']:
    scaler = RobustScaler()
    data[feature] = scaler.fit_transform(data[[feature]])
    scalers[feature] = scaler

# %%
# 시퀀스 생성 함수 정의
def create_sequences(data, sequence_length, target):
    X = []
    y = []
    data_values = data[features].values
    labels = data[target].values
    for i in range(len(data_values) - sequence_length):
        X.append(data_values[i:i+sequence_length])
        y.append(labels[i+sequence_length])
    return np.array(X), np.array(y)

# %%
# 데이터 생성
sequence_length = 60  # 시퀀스 길이
X, y = create_sequences(data, sequence_length, target='Price_Label')

# %%
# 시간 순서대로 데이터 분할
train_size = int(len(X) * 0.7)
val_size = int(len(X) * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size+val_size]
y_val = y[train_size:train_size+val_size]

X_test = X[train_size+val_size:]
y_test = y[train_size+val_size:]

# %%
# 클래스 분포 확인
unique, counts = np.unique(y_train, return_counts=True)
print("클래스 분포:", dict(zip(unique, counts)))
# Out:
# 클래스 분포: {0: 203, 1: 130158, 2: 259}

# %%
# 하이퍼 파라미터 설정
d_model = X_train.shape[2]
num_heads = 4
ff_dim = 64
num_layers = 2
dropout_rate = 0.1
num_classes = 3  # 레이블 클래스 수

# %%
# 포지셔널 인코딩 정의
class PositionalEncoding(layers.Layer):
    def __init__(self, sequence_length, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(sequence_length, d_model)
    
    def get_config(self):
        config = super().get_config().copy()
        return config
    
    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            np.arange(position)[:, np.newaxis],
            np.arange(d_model)[np.newaxis, :],
            d_model)
        
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)
    
    def get_angles(self, pos, i, d_model):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
        return pos * angle_rates
    
    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
# 트랜스포머 블록 정의
def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(inputs, inputs)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)
    
    # Feed Forward Network
    ffn_output = layers.Dense(ff_dim, activation='gelu', kernel_regularizer=regularizers.l2(1e-4))(out1)
    ffn_output = layers.Dense(head_size)(ffn_output)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

# %%
# 모델 정의
def create_model():
    inputs = layers.Input(shape=(sequence_length, d_model))
    x = PositionalEncoding(sequence_length, d_model)(inputs)
    
    for _ in range(num_layers):
        x = transformer_block(x, d_model, num_heads, ff_dim, dropout_rate)
    
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 60, 15)]     0           []
#
#  positional_encoding (Positiona  (None, 60, 15)      0           ['input_1[0][0]']
#  lEncoding)
#
#  multi_head_attention (MultiHea  (None, 60, 15)      3795        ['positional_encoding[0][0]',
#  dAttention)                                                      'positional_encoding[0][0]']
#
#  dropout (Dropout)              (None, 60, 15)       0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 60, 15)      0           ['positional_encoding[0][0]',
#  da)                                                              'dropout[0][0]']
#
#  layer_normalization (LayerNorm  (None, 60, 15)      30          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 60, 64)       1024        ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 60, 15)       975         ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 60, 15)       0           ['dense_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 60, 15)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 60, 15)      3795        ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 60, 15)       0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'dropout_2[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 60, 64)       1024        ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 60, 15)       975         ['dense_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 60, 15)       0           ['dense_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 60, 15)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 60, 15)      30          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  global_average_pooling1d (Glob  (None, 15)          0           ['layer_normalization_3[0][0]']
#  alAveragePooling1D)
#
#  dropout_4 (Dropout)            (None, 15)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 3)            48          ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 11,756
# Trainable params: 11,756
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 클래스 가중치 계산
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# %%
class_weights
# Out:
# {0: 214.48275862068965, 1: 0.3345165107023771, 2: 168.1081081081081}

# %%
# 모델 컴파일
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

# %%
# 모델 체크포인트 콜백 설정
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./model_transformer2/best_model_2_06.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# %%
# 콜백 리스트에 포함
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    checkpoint_callback
]

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=16,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 8164/8164 [==============================] - ETA: 0s - loss: 1.0788 - accuracy: 0.5367
# Epoch 1: val_loss improved from inf to 0.83711, saving model to ./model_transformer2\best_model_2_06.h5
# 8164/8164 [==============================] - 158s 19ms/step - loss: 1.0788 - accuracy: 0.5367 - val_loss: 0.8371 - val_accuracy: 0.7041
# Epoch 2/100
# 8164/8164 [==============================] - ETA: 0s - loss: 1.0380 - accuracy: 0.6091
# Epoch 2: val_loss improved from 0.83711 to 0.75522, saving model to ./model_transformer2\best_model_2_06.h5
# 8164/8164 [==============================] - 155s 19ms/step - loss: 1.0380 - accuracy: 0.6091 - val_loss: 0.7552 - val_accuracy: 0.7352
# Epoch 3/100
# 8164/8164 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.6344
# Epoch 3: val_loss did not improve from 0.75522
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.9975 - accuracy: 0.6344 - val_loss: 1.0153 - val_accuracy: 0.5748
# Epoch 4/100
# 8164/8164 [==============================] - ETA: 0s - loss: 0.9698 - accuracy: 0.6593
# Epoch 4: val_loss improved from 0.75522 to 0.60014, saving model to ./model_transformer2\best_model_2_06.h5
# 8164/8164 [==============================] - 153s 19ms/step - loss: 0.9698 - accuracy: 0.6593 - val_loss: 0.6001 - val_accuracy: 0.7822
# Epoch 5/100
# 8162/8164 [============================>.] - ETA: 0s - loss: 0.9434 - accuracy: 0.6905
# Epoch 5: val_loss did not improve from 0.60014
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.9432 - accuracy: 0.6905 - val_loss: 1.1053 - val_accuracy: 0.5556
# Epoch 6/100
# 8161/8164 [============================>.] - ETA: 0s - loss: 0.9215 - accuracy: 0.7019
# Epoch 6: val_loss improved from 0.60014 to 0.55550, saving model to ./model_transformer2\best_model_2_06.h5
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.9213 - accuracy: 0.7019 - val_loss: 0.5555 - val_accuracy: 0.8160
# Epoch 7/100
# 8162/8164 [============================>.] - ETA: 0s - loss: 0.8991 - accuracy: 0.7352
# Epoch 7: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.8990 - accuracy: 0.7352 - val_loss: 0.6425 - val_accuracy: 0.7625
# Epoch 8/100
# 8163/8164 [============================>.] - ETA: 0s - loss: 0.8897 - accuracy: 0.7499
# Epoch 8: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.8896 - accuracy: 0.7499 - val_loss: 0.8665 - val_accuracy: 0.6546
# Epoch 9/100
# 8164/8164 [==============================] - ETA: 0s - loss: 0.8805 - accuracy: 0.7460
# Epoch 9: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 151s 19ms/step - loss: 0.8805 - accuracy: 0.7460 - val_loss: 0.8579 - val_accuracy: 0.6659
# Epoch 10/100
# 8161/8164 [============================>.] - ETA: 0s - loss: 0.8861 - accuracy: 0.7530
# Epoch 10: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.8859 - accuracy: 0.7530 - val_loss: 0.7027 - val_accuracy: 0.7344
# Epoch 11/100
# 8164/8164 [==============================] - ETA: 0s - loss: 0.8611 - accuracy: 0.7688
# Epoch 11: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 156s 19ms/step - loss: 0.8611 - accuracy: 0.7688 - val_loss: 0.8329 - val_accuracy: 0.6776
# Epoch 12/100
# 8163/8164 [============================>.] - ETA: 0s - loss: 0.8348 - accuracy: 0.7592
# Epoch 12: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 155s 19ms/step - loss: 0.8347 - accuracy: 0.7592 - val_loss: 0.6219 - val_accuracy: 0.7609
# Epoch 13/100
# 8163/8164 [============================>.] - ETA: 0s - loss: 0.8587 - accuracy: 0.7559
# Epoch 13: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 154s 19ms/step - loss: 0.8586 - accuracy: 0.7558 - val_loss: 0.7366 - val_accuracy: 0.7310
# Epoch 14/100
# 8162/8164 [============================>.] - ETA: 0s - loss: 0.8429 - accuracy: 0.7654
# Epoch 14: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 155s 19ms/step - loss: 0.8427 - accuracy: 0.7654 - val_loss: 1.0767 - val_accuracy: 0.5501
# Epoch 15/100
# 8164/8164 [==============================] - ETA: 0s - loss: 0.8344 - accuracy: 0.7652
# Epoch 15: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 153s 19ms/step - loss: 0.8344 - accuracy: 0.7652 - val_loss: 0.5845 - val_accuracy: 0.7679
# Epoch 16/100
# 8163/8164 [============================>.] - ETA: 0s - loss: 0.8292 - accuracy: 0.7713
# Epoch 16: val_loss did not improve from 0.55550
# 8164/8164 [==============================] - 152s 19ms/step - loss: 0.8292 - accuracy: 0.7713 - val_loss: 0.9611 - val_accuracy: 0.6094

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 875/875 [==============================] - 7s 8ms/step - loss: 0.5305 - accuracy: 0.8099
# Test Accuracy: 0.8099

# %%
# 자세한 성능 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_classes))
# Out:
# 875/875 [==============================] - 6s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.01      0.36      0.02        89
#            1       1.00      0.81      0.90     27802
#            2       0.01      0.10      0.01       100
#
#     accuracy                           0.81     27991
#    macro avg       0.34      0.42      0.31     27991
# weighted avg       0.99      0.81      0.89     27991

# %%
import matplotlib.pyplot as plt
# 혼동 행렬 계산 및 시각화
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
# 정확도 시각화
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# 손실 시각화
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

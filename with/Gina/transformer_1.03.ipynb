# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
# Out:
# c:\ProgramData\anaconda3\envs\final_tensorflow\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\final_tensorflow\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# 1. 데이터 전처리
def create_classification_targets(data, columns, window_size=10, pred_offset=1):
    X = []
    y = []
    for i in range(len(data) - window_size - pred_offset + 1):
        # 10분 동안의 Close와 Volume 데이터
        X.append(data.iloc[i:i+window_size][columns].values)
        # 3분 뒤의 Close 가격 변화에 따른 클래스 설정
        future_close = data.iloc[i+window_size+pred_offset-1]['Close']
        current_close = data.iloc[i+window_size-1]['Close']
        
        # 가격 변화에 따라 클래스 설정: 상승(2), 보합(1), 하락(0)
        if future_close > current_close:
            y.append(2)  # 상승
        elif future_close < current_close:
            y.append(0)  # 하락
        else:
            y.append(1)  # 보합
    return np.array(X), np.array(y)

# 데이터 불러오기 및 전처리
data = pd.read_csv('./000660.csv', parse_dates=['Unnamed: 0'])
data = data.rename(columns={'Unnamed: 0': 'Time', '매수량': 'BuyVolume', '매도량': 'SellVolume', '종가': 'Close', '저가': 'Low'})
data['Power'] = data['BuyVolume'] - data['SellVolume']
columns = ['Close', 'Power', 'Low']
data = data[['Time', 'Close', 'Power', 'Low']].dropna()

X, y = create_classification_targets(data, columns)

# 데이터 정규화
scaler = RobustScaler()
X_scaled = np.array([scaler.fit_transform(sample) for sample in X])

# 학습/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(X_train.shape)  # (samples, 10, 2)
print(y_train.shape)  # (samples,)
# Out:
# (149464, 10, 3)
# (149464,)

# %%
X.shape
X.shape[1:]
# Out:
# (10, 3)

# %%
# y 클래스 데이터 분포 확인
print(np.bincount(y_train))
# Out:
# [44198 61632 43634]

# %%
# 클래스 가중치 계산
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights_dict = {i : class_weights[i] for i in range(len(class_weights))}

# %%
# 2. Positional Encoding 구현
def positional_encoding(max_len, d_model):
    pos = np.arange(max_len)[:, np.newaxis]
    i = np.arange(d_model)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    angle_rads = pos * angle_rates

    # 짝수 인덱스에 대해 sin 적용
    sines = np.sin(angle_rads[:, 0::2])

    # 홀수 인덱스에 대해 cos 적용
    cosines = np.cos(angle_rads[:, 1::2])

    pos_encoding = np.concatenate([sines, cosines], axis=-1)
    return pos_encoding

def add_positional_encoding(inputs, max_len, d_model):
    pos_encoding = positional_encoding(max_len, d_model)
    pos_encoding = tf.cast(pos_encoding, dtype=tf.float32)
    
    pos_encoded_inputs = inputs + pos_encoding[:tf.shape(inputs)[1], :]
    return pos_encoded_inputs

# 3. Transformer 블록 구현
class TransformerBlock(layers.Layer):
    def __init__(self, d_model, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate
        
        self.att1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.att2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.ffn = tf.keras.Sequential(
            [layers.Dense(ff_dim, activation="gelu"), layers.Dense(d_model)]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
        self.dropout3 = layers.Dropout(rate)

    def call(self, inputs):
        attn_output1 = self.att1(inputs, inputs)
        attn_output1 = self.dropout1(attn_output1)
        out1 = self.layernorm1(inputs + attn_output1)
        # attn_output2 = self.att2(out1, out1)
        # attn_output2 = self.dropout2(attn_output2)
        # out2 = self.layernorm1(out1 + attn_output2)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout1(ffn_output)
        return self.layernorm2(out1 + ffn_output)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            'd_model': self.d_model,
            'num_heads': self.num_heads,
            'ff_dim': self.ff_dim,
            'rate': self.rate
        })
        return config

# 4. Transformer 모델 구성
def create_transformer_model(input_shape, num_heads, ff_dim, d_model, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # 임베딩 및 위치 인코딩
    # embedding_layer = layers.Dense(d_model)(inputs)
    pos_encoded_inputs = add_positional_encoding(inputs, max_len=input_shape[0], d_model=d_model)

    # Transformer 블록 적용
    transformer_block = TransformerBlock(d_model, num_heads, ff_dim)
    x = transformer_block(pos_encoded_inputs)
    
    # 출력 레이어
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation="gelu")(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=100,
    verbose=1,
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    'best_model_3.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

callbacks = [early_stopping, model_checkpoint]

# %%
# 5. 모델 생성 및 학습
input_shape = X.shape[1:]  # 10분 동안의 데이터 
model = create_transformer_model(input_shape, num_heads=1, ff_dim=128, d_model=input_shape[1], num_classes=3)

# 모델 컴파일
model.compile(optimizer=tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# 모델 학습
history = model.fit(X_train, 
                    y_train, 
                    epochs=1000, 
                    batch_size=128, 
                    validation_data=(X_test, y_test), 
                    class_weight=class_weights_dict,
                    callbacks=callbacks
                    )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 10, 3)]      0           []
#
#  tf.compat.v1.shape_1 (TFOpLamb  (3,)                0           ['input_2[0][0]']
#  da)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.stack_1 (TFOpLambda)        (2,)                 0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.strided_slice_1 (TFOpLambda  (10, 3)             0           ['tf.stack_1[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (None, 10, 3)       0           ['input_2[0][0]',
#  mbda)                                                            'tf.strided_slice_1[0][0]']
#
#  transformer_block (Transformer  (None, 10, 3)       959         ['tf.__operators__.add_1[0][0]']
#  Block)
#
#  global_average_pooling1d (Glob  (None, 3)           0           ['transformer_block[0][0]']
#  alAveragePooling1D)
#
#  dense_2 (Dense)                (None, 128)          512         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 1,858
# Trainable params: 1,858
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0984 - accuracy: 0.3310
# Epoch 1: val_loss improved from inf to 1.09776, saving model to best_model_3.h5
# 1168/1168 [==============================] - 20s 15ms/step - loss: 1.0984 - accuracy: 0.3310 - val_loss: 1.0978 - val_accuracy: 0.3331
# Epoch 2/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0970 - accuracy: 0.3379
# Epoch 2: val_loss did not improve from 1.09776
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0970 - accuracy: 0.3380 - val_loss: 1.0980 - val_accuracy: 0.3368
# Epoch 3/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0966 - accuracy: 0.3430
# Epoch 3: val_loss improved from 1.09776 to 1.09606, saving model to best_model_3.h5
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0966 - accuracy: 0.3430 - val_loss: 1.0961 - val_accuracy: 0.3544
# Epoch 4/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0963 - accuracy: 0.3523
# Epoch 4: val_loss did not improve from 1.09606
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0963 - accuracy: 0.3523 - val_loss: 1.0970 - val_accuracy: 0.3572
# Epoch 5/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0958 - accuracy: 0.3589
# Epoch 5: val_loss improved from 1.09606 to 1.09460, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0958 - accuracy: 0.3588 - val_loss: 1.0946 - val_accuracy: 0.3605
# Epoch 6/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0959 - accuracy: 0.3629
# Epoch 6: val_loss did not improve from 1.09460
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0959 - accuracy: 0.3629 - val_loss: 1.0974 - val_accuracy: 0.3601
# Epoch 7/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0958 - accuracy: 0.3615
# Epoch 7: val_loss improved from 1.09460 to 1.09331, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0958 - accuracy: 0.3615 - val_loss: 1.0933 - val_accuracy: 0.3741
# Epoch 8/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0959 - accuracy: 0.3610
# Epoch 8: val_loss improved from 1.09331 to 1.09322, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0959 - accuracy: 0.3610 - val_loss: 1.0932 - val_accuracy: 0.3752
# Epoch 9/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0959 - accuracy: 0.3612
# Epoch 9: val_loss did not improve from 1.09322
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0959 - accuracy: 0.3612 - val_loss: 1.0944 - val_accuracy: 0.3658
# Epoch 10/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0960 - accuracy: 0.3609
# Epoch 10: val_loss improved from 1.09322 to 1.09129, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0960 - accuracy: 0.3609 - val_loss: 1.0913 - val_accuracy: 0.3816
# Epoch 11/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0961 - accuracy: 0.3621
# Epoch 11: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0961 - accuracy: 0.3621 - val_loss: 1.0932 - val_accuracy: 0.3756
# Epoch 12/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0959 - accuracy: 0.3637
# Epoch 12: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0959 - accuracy: 0.3638 - val_loss: 1.0945 - val_accuracy: 0.3678
# Epoch 13/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0958 - accuracy: 0.3613
# Epoch 13: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0959 - accuracy: 0.3613 - val_loss: 1.0928 - val_accuracy: 0.3764
# Epoch 14/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0958 - accuracy: 0.3624
# Epoch 14: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0957 - accuracy: 0.3624 - val_loss: 1.0958 - val_accuracy: 0.3666
# Epoch 15/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0956 - accuracy: 0.3617
# Epoch 15: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0956 - accuracy: 0.3617 - val_loss: 1.0951 - val_accuracy: 0.3652
# Epoch 16/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0955 - accuracy: 0.3618
# Epoch 16: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0955 - accuracy: 0.3618 - val_loss: 1.0922 - val_accuracy: 0.3761
# Epoch 17/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0955 - accuracy: 0.3632
# Epoch 17: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0955 - accuracy: 0.3631 - val_loss: 1.0942 - val_accuracy: 0.3663
# Epoch 18/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0955 - accuracy: 0.3646
# Epoch 18: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0955 - accuracy: 0.3647 - val_loss: 1.0928 - val_accuracy: 0.3722
# Epoch 19/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0954 - accuracy: 0.3663
# Epoch 19: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0954 - accuracy: 0.3663 - val_loss: 1.0930 - val_accuracy: 0.3742
# Epoch 20/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0955 - accuracy: 0.3657
# Epoch 20: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0955 - accuracy: 0.3657 - val_loss: 1.0915 - val_accuracy: 0.3781
# Epoch 21/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0956 - accuracy: 0.3659
# Epoch 21: val_loss did not improve from 1.09129
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0955 - accuracy: 0.3659 - val_loss: 1.0915 - val_accuracy: 0.3775
# Epoch 22/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0954 - accuracy: 0.3639
# Epoch 22: val_loss improved from 1.09129 to 1.08952, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0954 - accuracy: 0.3640 - val_loss: 1.0895 - val_accuracy: 0.3832
# Epoch 23/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3659
# Epoch 23: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3659 - val_loss: 1.1001 - val_accuracy: 0.3487
# Epoch 24/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0954 - accuracy: 0.3648
# Epoch 24: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0954 - accuracy: 0.3649 - val_loss: 1.0912 - val_accuracy: 0.3796
# Epoch 25/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0954 - accuracy: 0.3689
# Epoch 25: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0954 - accuracy: 0.3689 - val_loss: 1.0939 - val_accuracy: 0.3644
# Epoch 26/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3706
# Epoch 26: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3706 - val_loss: 1.0963 - val_accuracy: 0.3678
# Epoch 27/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3713
# Epoch 27: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3713 - val_loss: 1.0923 - val_accuracy: 0.3796
# Epoch 28/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3697
# Epoch 28: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3697 - val_loss: 1.0915 - val_accuracy: 0.3823
# Epoch 29/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0949 - accuracy: 0.3732
# Epoch 29: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0950 - accuracy: 0.3732 - val_loss: 1.0978 - val_accuracy: 0.3652
# Epoch 30/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3714
# Epoch 30: val_loss did not improve from 1.08952
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3714 - val_loss: 1.0921 - val_accuracy: 0.3786
# Epoch 31/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3709
# Epoch 31: val_loss improved from 1.08952 to 1.08923, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3709 - val_loss: 1.0892 - val_accuracy: 0.3878
# Epoch 32/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3708
# Epoch 32: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 16s 14ms/step - loss: 1.0950 - accuracy: 0.3709 - val_loss: 1.0949 - val_accuracy: 0.3673
# Epoch 33/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3698
# Epoch 33: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 14ms/step - loss: 1.0950 - accuracy: 0.3698 - val_loss: 1.0921 - val_accuracy: 0.3768
# Epoch 34/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3722
# Epoch 34: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0950 - accuracy: 0.3722 - val_loss: 1.0943 - val_accuracy: 0.3725
# Epoch 35/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3728
# Epoch 35: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3728 - val_loss: 1.1003 - val_accuracy: 0.3583
# Epoch 36/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3726
# Epoch 36: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0950 - accuracy: 0.3725 - val_loss: 1.0975 - val_accuracy: 0.3659
# Epoch 37/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3733
# Epoch 37: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3733 - val_loss: 1.0920 - val_accuracy: 0.3774
# Epoch 38/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3717
# Epoch 38: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3717 - val_loss: 1.0955 - val_accuracy: 0.3672
# Epoch 39/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3714
# Epoch 39: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3713 - val_loss: 1.0896 - val_accuracy: 0.3885
# Epoch 40/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3721
# Epoch 40: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3721 - val_loss: 1.0894 - val_accuracy: 0.3866
# Epoch 41/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3698
# Epoch 41: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3698 - val_loss: 1.0920 - val_accuracy: 0.3775
# Epoch 42/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3729
# Epoch 42: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 16s 14ms/step - loss: 1.0950 - accuracy: 0.3730 - val_loss: 1.0915 - val_accuracy: 0.3795
# Epoch 43/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3704
# Epoch 43: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3704 - val_loss: 1.0970 - val_accuracy: 0.3639
# Epoch 44/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3717
# Epoch 44: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3717 - val_loss: 1.0905 - val_accuracy: 0.3809
# Epoch 45/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3693
# Epoch 45: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3693 - val_loss: 1.0921 - val_accuracy: 0.3764
# Epoch 46/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3692
# Epoch 46: val_loss did not improve from 1.08923
# 1168/1168 [==============================] - 17s 14ms/step - loss: 1.0951 - accuracy: 0.3692 - val_loss: 1.0937 - val_accuracy: 0.3694
# Epoch 47/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3694
# Epoch 47: val_loss improved from 1.08923 to 1.08703, saving model to best_model_3.h5
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3694 - val_loss: 1.0870 - val_accuracy: 0.3943
# Epoch 48/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3693
# Epoch 48: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3693 - val_loss: 1.0922 - val_accuracy: 0.3684
# Epoch 49/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3690
# Epoch 49: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3690 - val_loss: 1.0907 - val_accuracy: 0.3757
# Epoch 50/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3721
# Epoch 50: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3721 - val_loss: 1.0976 - val_accuracy: 0.3654
# Epoch 51/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3695
# Epoch 51: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3695 - val_loss: 1.0934 - val_accuracy: 0.3755
# Epoch 52/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3704
# Epoch 52: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3704 - val_loss: 1.0985 - val_accuracy: 0.3603
# Epoch 53/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3692
# Epoch 53: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3692 - val_loss: 1.0960 - val_accuracy: 0.3646
# Epoch 54/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3695
# Epoch 54: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3695 - val_loss: 1.0963 - val_accuracy: 0.3658
# Epoch 55/1000
# 1164/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3703
# Epoch 55: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0950 - accuracy: 0.3702 - val_loss: 1.0933 - val_accuracy: 0.3732
# Epoch 56/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3681
# Epoch 56: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3681 - val_loss: 1.0935 - val_accuracy: 0.3720
# Epoch 57/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3693
# Epoch 57: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3691 - val_loss: 1.0966 - val_accuracy: 0.3621
# Epoch 58/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3681
# Epoch 58: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3680 - val_loss: 1.1046 - val_accuracy: 0.3420
# Epoch 59/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3681
# Epoch 59: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3681 - val_loss: 1.0962 - val_accuracy: 0.3636
# Epoch 60/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3664
# Epoch 60: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3664 - val_loss: 1.0954 - val_accuracy: 0.3674
# Epoch 61/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3691
# Epoch 61: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3691 - val_loss: 1.0937 - val_accuracy: 0.3697
# Epoch 62/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3691
# Epoch 62: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3692 - val_loss: 1.0948 - val_accuracy: 0.3633
# Epoch 63/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3690
# Epoch 63: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3689 - val_loss: 1.0950 - val_accuracy: 0.3607
# Epoch 64/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3688
# Epoch 64: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3688 - val_loss: 1.0872 - val_accuracy: 0.3923
# Epoch 65/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3677
# Epoch 65: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3677 - val_loss: 1.0934 - val_accuracy: 0.3661
# Epoch 66/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3692
# Epoch 66: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0954 - accuracy: 0.3692 - val_loss: 1.0973 - val_accuracy: 0.3596
# Epoch 67/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3693
# Epoch 67: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0951 - accuracy: 0.3693 - val_loss: 1.0954 - val_accuracy: 0.3628
# Epoch 68/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3698
# Epoch 68: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3698 - val_loss: 1.0951 - val_accuracy: 0.3676
# Epoch 69/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3710
# Epoch 69: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3711 - val_loss: 1.0970 - val_accuracy: 0.3562
# Epoch 70/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3696
# Epoch 70: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3696 - val_loss: 1.0937 - val_accuracy: 0.3725
# Epoch 71/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3694
# Epoch 71: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3694 - val_loss: 1.0955 - val_accuracy: 0.3723
# Epoch 72/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3697
# Epoch 72: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3698 - val_loss: 1.0902 - val_accuracy: 0.3818
# Epoch 73/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3712
# Epoch 73: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3713 - val_loss: 1.0949 - val_accuracy: 0.3692
# Epoch 74/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3702
# Epoch 74: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3702 - val_loss: 1.0951 - val_accuracy: 0.3702
# Epoch 75/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3704
# Epoch 75: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3704 - val_loss: 1.0948 - val_accuracy: 0.3704
# Epoch 76/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 76: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3707 - val_loss: 1.0965 - val_accuracy: 0.3624
# Epoch 77/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3707
# Epoch 77: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3708 - val_loss: 1.0967 - val_accuracy: 0.3626
# Epoch 78/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3705
# Epoch 78: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3705 - val_loss: 1.0880 - val_accuracy: 0.3912
# Epoch 79/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3697
# Epoch 79: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3697 - val_loss: 1.0918 - val_accuracy: 0.3705
# Epoch 80/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3691
# Epoch 80: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0953 - accuracy: 0.3691 - val_loss: 1.0947 - val_accuracy: 0.3681
# Epoch 81/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3693
# Epoch 81: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3693 - val_loss: 1.0887 - val_accuracy: 0.3855
# Epoch 82/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3683
# Epoch 82: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3682 - val_loss: 1.0960 - val_accuracy: 0.3574
# Epoch 83/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3692
# Epoch 83: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3692 - val_loss: 1.0958 - val_accuracy: 0.3684
# Epoch 84/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3715
# Epoch 84: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3715 - val_loss: 1.0924 - val_accuracy: 0.3661
# Epoch 85/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3691
# Epoch 85: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0953 - accuracy: 0.3691 - val_loss: 1.0925 - val_accuracy: 0.3793
# Epoch 86/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3689
# Epoch 86: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0952 - accuracy: 0.3689 - val_loss: 1.0890 - val_accuracy: 0.3863
# Epoch 87/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3708
# Epoch 87: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3707 - val_loss: 1.0980 - val_accuracy: 0.3635
# Epoch 88/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3708
# Epoch 88: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3708 - val_loss: 1.0958 - val_accuracy: 0.3685
# Epoch 89/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0954 - accuracy: 0.3715
# Epoch 89: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0954 - accuracy: 0.3715 - val_loss: 1.0917 - val_accuracy: 0.3757
# Epoch 90/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3703
# Epoch 90: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3703 - val_loss: 1.0932 - val_accuracy: 0.3749
# Epoch 91/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3698
# Epoch 91: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3698 - val_loss: 1.0958 - val_accuracy: 0.3692
# Epoch 92/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3701
# Epoch 92: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0953 - accuracy: 0.3701 - val_loss: 1.0878 - val_accuracy: 0.3944
# Epoch 93/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3725
# Epoch 93: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3725 - val_loss: 1.0949 - val_accuracy: 0.3647
# Epoch 94/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3696
# Epoch 94: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3697 - val_loss: 1.0924 - val_accuracy: 0.3719
# Epoch 95/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3696
# Epoch 95: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3696 - val_loss: 1.0950 - val_accuracy: 0.3672
# Epoch 96/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3690
# Epoch 96: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3690 - val_loss: 1.0947 - val_accuracy: 0.3695
# Epoch 97/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3696
# Epoch 97: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3696 - val_loss: 1.0886 - val_accuracy: 0.3882
# Epoch 98/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3701
# Epoch 98: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3701 - val_loss: 1.0902 - val_accuracy: 0.3829
# Epoch 99/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3702
# Epoch 99: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3702 - val_loss: 1.1023 - val_accuracy: 0.3532
# Epoch 100/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3690
# Epoch 100: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3690 - val_loss: 1.0977 - val_accuracy: 0.3604
# Epoch 101/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3692
# Epoch 101: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3691 - val_loss: 1.0929 - val_accuracy: 0.3771
# Epoch 102/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3693
# Epoch 102: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3693 - val_loss: 1.0881 - val_accuracy: 0.3935
# Epoch 103/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 103: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3707 - val_loss: 1.0895 - val_accuracy: 0.3845
# Epoch 104/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3708
# Epoch 104: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3708 - val_loss: 1.1024 - val_accuracy: 0.3522
# Epoch 105/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3702
# Epoch 105: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3702 - val_loss: 1.0961 - val_accuracy: 0.3668
# Epoch 106/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3713
# Epoch 106: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 17s 15ms/step - loss: 1.0950 - accuracy: 0.3712 - val_loss: 1.0974 - val_accuracy: 0.3665
# Epoch 107/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3709
# Epoch 107: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3709 - val_loss: 1.0929 - val_accuracy: 0.3694
# Epoch 108/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3700
# Epoch 108: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3701 - val_loss: 1.0910 - val_accuracy: 0.3784
# Epoch 109/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3691
# Epoch 109: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3691 - val_loss: 1.0929 - val_accuracy: 0.3713
# Epoch 110/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3714
# Epoch 110: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3713 - val_loss: 1.0927 - val_accuracy: 0.3730
# Epoch 111/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 111: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3707 - val_loss: 1.0988 - val_accuracy: 0.3620
# Epoch 112/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3701
# Epoch 112: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3701 - val_loss: 1.0919 - val_accuracy: 0.3740
# Epoch 113/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3697
# Epoch 113: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3697 - val_loss: 1.0884 - val_accuracy: 0.3889
# Epoch 114/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3675
# Epoch 114: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3675 - val_loss: 1.0887 - val_accuracy: 0.3912
# Epoch 115/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3691
# Epoch 115: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3691 - val_loss: 1.0900 - val_accuracy: 0.3795
# Epoch 116/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3689
# Epoch 116: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3689 - val_loss: 1.0953 - val_accuracy: 0.3596
# Epoch 117/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3702
# Epoch 117: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3701 - val_loss: 1.0918 - val_accuracy: 0.3785
# Epoch 118/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3710
# Epoch 118: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3710 - val_loss: 1.0945 - val_accuracy: 0.3675
# Epoch 119/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3706
# Epoch 119: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3706 - val_loss: 1.0903 - val_accuracy: 0.3781
# Epoch 120/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3708
# Epoch 120: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3709 - val_loss: 1.0933 - val_accuracy: 0.3742
# Epoch 121/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3712
# Epoch 121: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3712 - val_loss: 1.0909 - val_accuracy: 0.3781
# Epoch 122/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3716
# Epoch 122: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3717 - val_loss: 1.0915 - val_accuracy: 0.3761
# Epoch 123/1000
# 1164/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3719
# Epoch 123: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3719 - val_loss: 1.0935 - val_accuracy: 0.3751
# Epoch 124/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3720
# Epoch 124: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3720 - val_loss: 1.0906 - val_accuracy: 0.3783
# Epoch 125/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3701
# Epoch 125: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3702 - val_loss: 1.0949 - val_accuracy: 0.3726
# Epoch 126/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3726
# Epoch 126: val_loss did not improve from 1.08703
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3726 - val_loss: 1.0955 - val_accuracy: 0.3713
# Epoch 127/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3723
# Epoch 127: val_loss improved from 1.08703 to 1.08686, saving model to best_model_3.h5
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3724 - val_loss: 1.0869 - val_accuracy: 0.3958
# Epoch 128/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3726
# Epoch 128: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3726 - val_loss: 1.0943 - val_accuracy: 0.3755
# Epoch 129/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3708
# Epoch 129: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3708 - val_loss: 1.0911 - val_accuracy: 0.3822
# Epoch 130/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3726
# Epoch 130: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3727 - val_loss: 1.0983 - val_accuracy: 0.3626
# Epoch 131/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3715
# Epoch 131: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3715 - val_loss: 1.0904 - val_accuracy: 0.3837
# Epoch 132/1000
# 1164/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3695
# Epoch 132: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3696 - val_loss: 1.0947 - val_accuracy: 0.3711
# Epoch 133/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3696
# Epoch 133: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3697 - val_loss: 1.0914 - val_accuracy: 0.3765
# Epoch 134/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3702
# Epoch 134: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3702 - val_loss: 1.0952 - val_accuracy: 0.3706
# Epoch 135/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3707
# Epoch 135: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3707 - val_loss: 1.0961 - val_accuracy: 0.3660
# Epoch 136/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3709
# Epoch 136: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3708 - val_loss: 1.0899 - val_accuracy: 0.3829
# Epoch 137/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3725
# Epoch 137: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3725 - val_loss: 1.0925 - val_accuracy: 0.3787
# Epoch 138/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3712
# Epoch 138: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3713 - val_loss: 1.0874 - val_accuracy: 0.3899
# Epoch 139/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3720
# Epoch 139: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3720 - val_loss: 1.0917 - val_accuracy: 0.3741
# Epoch 140/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3719
# Epoch 140: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3719 - val_loss: 1.1045 - val_accuracy: 0.3546
# Epoch 141/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3704
# Epoch 141: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3703 - val_loss: 1.0948 - val_accuracy: 0.3675
# Epoch 142/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3697
# Epoch 142: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3697 - val_loss: 1.0926 - val_accuracy: 0.3769
# Epoch 143/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3715
# Epoch 143: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3714 - val_loss: 1.0893 - val_accuracy: 0.3830
# Epoch 144/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3718
# Epoch 144: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3718 - val_loss: 1.0923 - val_accuracy: 0.3773
# Epoch 145/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3708
# Epoch 145: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3708 - val_loss: 1.0948 - val_accuracy: 0.3709
# Epoch 146/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3682
# Epoch 146: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3682 - val_loss: 1.0938 - val_accuracy: 0.3708
# Epoch 147/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3697
# Epoch 147: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3698 - val_loss: 1.0923 - val_accuracy: 0.3711
# Epoch 148/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3695
# Epoch 148: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3695 - val_loss: 1.0895 - val_accuracy: 0.3766
# Epoch 149/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3685
# Epoch 149: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3684 - val_loss: 1.0894 - val_accuracy: 0.3781
# Epoch 150/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0949 - accuracy: 0.3699
# Epoch 150: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0949 - accuracy: 0.3700 - val_loss: 1.0925 - val_accuracy: 0.3729
# Epoch 151/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3695
# Epoch 151: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3696 - val_loss: 1.0904 - val_accuracy: 0.3763
# Epoch 152/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3711
# Epoch 152: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3711 - val_loss: 1.0961 - val_accuracy: 0.3683
# Epoch 153/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0949 - accuracy: 0.3703
# Epoch 153: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0949 - accuracy: 0.3703 - val_loss: 1.0913 - val_accuracy: 0.3788
# Epoch 154/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 154: val_loss did not improve from 1.08686
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3707 - val_loss: 1.0932 - val_accuracy: 0.3715
# Epoch 155/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3711
# Epoch 155: val_loss did not improve from 1.08686
# ...
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3703 - val_loss: 1.1006 - val_accuracy: 0.3605
# Epoch 230/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3701
# Epoch 230: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3701 - val_loss: 1.0932 - val_accuracy: 0.3730
# Epoch 231/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3688
# Epoch 231: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3688 - val_loss: 1.0940 - val_accuracy: 0.3710
# Epoch 232/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3711
# Epoch 232: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0953 - accuracy: 0.3711 - val_loss: 1.0968 - val_accuracy: 0.3669
# Epoch 233/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3701
# Epoch 233: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3701 - val_loss: 1.0927 - val_accuracy: 0.3709
# Epoch 234/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3718
# Epoch 234: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3718 - val_loss: 1.0927 - val_accuracy: 0.3783
# Epoch 235/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3712
# Epoch 235: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3712 - val_loss: 1.0966 - val_accuracy: 0.3690
# Epoch 236/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3722
# Epoch 236: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3722 - val_loss: 1.0914 - val_accuracy: 0.3724
# Epoch 237/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3700
# Epoch 237: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3700 - val_loss: 1.0959 - val_accuracy: 0.3682
# Epoch 238/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3693
# Epoch 238: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3693 - val_loss: 1.0946 - val_accuracy: 0.3668
# Epoch 239/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3702
# Epoch 239: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3702 - val_loss: 1.0939 - val_accuracy: 0.3632
# Epoch 240/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3700
# Epoch 240: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3699 - val_loss: 1.0982 - val_accuracy: 0.3590
# Epoch 241/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3695
# Epoch 241: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0953 - accuracy: 0.3695 - val_loss: 1.0887 - val_accuracy: 0.3860
# Epoch 242/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3703
# Epoch 242: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3703 - val_loss: 1.0962 - val_accuracy: 0.3641
# Epoch 243/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3724
# Epoch 243: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3724 - val_loss: 1.0914 - val_accuracy: 0.3740
# Epoch 244/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3692
# Epoch 244: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3692 - val_loss: 1.0931 - val_accuracy: 0.3756
# Epoch 245/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3708
# Epoch 245: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3708 - val_loss: 1.0948 - val_accuracy: 0.3688
# Epoch 246/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3689
# Epoch 246: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0953 - accuracy: 0.3689 - val_loss: 1.0934 - val_accuracy: 0.3755
# Epoch 247/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3720
# Epoch 247: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3720 - val_loss: 1.0933 - val_accuracy: 0.3773
# Epoch 248/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3719
# Epoch 248: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3719 - val_loss: 1.0969 - val_accuracy: 0.3680
# Epoch 249/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0954 - accuracy: 0.3704
# Epoch 249: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0954 - accuracy: 0.3704 - val_loss: 1.0913 - val_accuracy: 0.3825
# Epoch 250/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3701
# Epoch 250: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3702 - val_loss: 1.0901 - val_accuracy: 0.3810
# Epoch 251/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3703
# Epoch 251: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0951 - accuracy: 0.3702 - val_loss: 1.0987 - val_accuracy: 0.3612
# Epoch 252/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3701
# Epoch 252: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3701 - val_loss: 1.0963 - val_accuracy: 0.3625
# Epoch 253/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3683
# Epoch 253: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3683 - val_loss: 1.0940 - val_accuracy: 0.3684
# Epoch 254/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3703
# Epoch 254: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3703 - val_loss: 1.0916 - val_accuracy: 0.3769
# Epoch 255/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3680
# Epoch 255: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0951 - accuracy: 0.3680 - val_loss: 1.0914 - val_accuracy: 0.3734
# Epoch 256/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3677
# Epoch 256: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3677 - val_loss: 1.0971 - val_accuracy: 0.3655
# Epoch 257/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3682
# Epoch 257: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3682 - val_loss: 1.0901 - val_accuracy: 0.3837
# Epoch 258/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3712
# Epoch 258: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3712 - val_loss: 1.0916 - val_accuracy: 0.3688
# Epoch 259/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3701
# Epoch 259: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3700 - val_loss: 1.1004 - val_accuracy: 0.3483
# Epoch 260/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3707
# Epoch 260: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3707 - val_loss: 1.0994 - val_accuracy: 0.3563
# Epoch 261/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3702
# Epoch 261: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0952 - accuracy: 0.3702 - val_loss: 1.0948 - val_accuracy: 0.3671
# Epoch 262/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3697
# Epoch 262: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3696 - val_loss: 1.0937 - val_accuracy: 0.3685
# Epoch 263/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3709
# Epoch 263: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3709 - val_loss: 1.0909 - val_accuracy: 0.3777
# Epoch 264/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3714
# Epoch 264: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0952 - accuracy: 0.3714 - val_loss: 1.0915 - val_accuracy: 0.3752
# Epoch 265/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3714
# Epoch 265: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3714 - val_loss: 1.0905 - val_accuracy: 0.3794
# Epoch 266/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3697
# Epoch 266: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3697 - val_loss: 1.0956 - val_accuracy: 0.3689
# Epoch 267/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3684
# Epoch 267: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0953 - accuracy: 0.3684 - val_loss: 1.0894 - val_accuracy: 0.3820
# Epoch 268/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.3711
# Epoch 268: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0953 - accuracy: 0.3711 - val_loss: 1.0935 - val_accuracy: 0.3698
# Epoch 269/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3693
# Epoch 269: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3693 - val_loss: 1.0931 - val_accuracy: 0.3692
# Epoch 270/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 270: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3707 - val_loss: 1.1050 - val_accuracy: 0.3311
# Epoch 271/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3703
# Epoch 271: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0951 - accuracy: 0.3702 - val_loss: 1.1001 - val_accuracy: 0.3571
# Epoch 272/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3707
# Epoch 272: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3708 - val_loss: 1.0895 - val_accuracy: 0.3839
# Epoch 273/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3719
# Epoch 273: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3719 - val_loss: 1.0926 - val_accuracy: 0.3708
# Epoch 274/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3695
# Epoch 274: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3695 - val_loss: 1.0924 - val_accuracy: 0.3751
# Epoch 275/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3714
# Epoch 275: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3714 - val_loss: 1.0923 - val_accuracy: 0.3725
# Epoch 276/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3708
# Epoch 276: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3708 - val_loss: 1.0917 - val_accuracy: 0.3752
# Epoch 277/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3696
# Epoch 277: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3695 - val_loss: 1.0963 - val_accuracy: 0.3651
# Epoch 278/1000
# 1165/1168 [============================>.] - ETA: 0s - loss: 1.0953 - accuracy: 0.3696
# Epoch 278: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0953 - accuracy: 0.3696 - val_loss: 1.0955 - val_accuracy: 0.3684
# Epoch 279/1000
# 1167/1168 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.3705
# Epoch 279: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3705 - val_loss: 1.0899 - val_accuracy: 0.3845
# Epoch 280/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0951 - accuracy: 0.3722
# Epoch 280: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0951 - accuracy: 0.3722 - val_loss: 1.1007 - val_accuracy: 0.3609
# Epoch 281/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3724
# Epoch 281: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0950 - accuracy: 0.3724 - val_loss: 1.0897 - val_accuracy: 0.3877
# Epoch 282/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.3720
# Epoch 282: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0950 - accuracy: 0.3720 - val_loss: 1.0889 - val_accuracy: 0.3866
# Epoch 283/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0952 - accuracy: 0.3706
# Epoch 283: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0952 - accuracy: 0.3706 - val_loss: 1.0889 - val_accuracy: 0.3900
# Epoch 284/1000
# 1166/1168 [============================>.] - ETA: 0s - loss: 1.0950 - accuracy: 0.3721Restoring model weights from the end of the best epoch: 184.
#
# Epoch 284: val_loss did not improve from 1.08628
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0950 - accuracy: 0.3721 - val_loss: 1.1002 - val_accuracy: 0.3581
# Epoch 284: early stopping

# %%
# 성능 평가 지표
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
# Out:
# 1168/1168 [==============================] - 5s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.35      0.25      0.29     11254
#            1       0.43      0.70      0.53     15321
#            2       0.31      0.12      0.17     10791
#
#     accuracy                           0.40     37366
#    macro avg       0.36      0.36      0.33     37366
# weighted avg       0.37      0.40      0.36     37366

# %%
import matplotlib.pyplot as plt

# 손실 시각화
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 시각화
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
# 1. 데이터 전처리
def create_classification_targets(data, window_size=10, pred_offset=1):
    X = []
    y = []
    for i in range(len(data) - window_size - pred_offset + 1):
        # 10분 동안의 Close와 Volume 데이터
        X.append(data.iloc[i:i+window_size][['Close', 'Volume']].values)
        # 3분 뒤의 Close 가격 변화에 따른 클래스 설정
        future_close = data.iloc[i+window_size+pred_offset-1]['Close']
        current_close = data.iloc[i+window_size-1]['Close']
        
        # 가격 변화에 따라 클래스 설정: 상승(2), 보합(1), 하락(0)
        if future_close > current_close:
            y.append(2)  # 상승
        elif future_close < current_close:
            y.append(0)  # 하락
        else:
            y.append(1)  # 보합
    return np.array(X), np.array(y)

# 데이터 불러오기 및 전처리
data = pd.read_csv('./000660.csv', parse_dates=['Unnamed: 0'])
data = data.rename(columns={'Unnamed: 0': 'Time', '거래량': 'Volume', '종가': 'Close'})
data = data[['Time', 'Close', 'Volume']].dropna()

X, y = create_classification_targets(data)

# 데이터 정규화
scaler = MinMaxScaler()
X_scaled = np.array([scaler.fit_transform(sample) for sample in X])

# 학습/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(X_train.shape)  # (samples, 10, 2)
print(y_train.shape)  # (samples,)
# Out:
# (149464, 10, 2)
# (149464,)

# %%
print("X_train shape:", X_train.shape)  # (num_samples, 10, 2)
print("y_train shape:", y_train.shape)  # (num_samples,)
# Out:
# X_train shape: (149464, 10, 2)
# y_train shape: (149464,)

# %%
# 2. Positional Encoding 구현
def positional_encoding(max_len, d_model):
    pos = np.arange(max_len)[:, np.newaxis]
    i = np.arange(d_model)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    angle_rads = pos * angle_rates

    # 짝수 인덱스에 대해 sin 적용
    sines = np.sin(angle_rads[:, 0::2])

    # 홀수 인덱스에 대해 cos 적용
    cosines = np.cos(angle_rads[:, 1::2])

    pos_encoding = np.concatenate([sines, cosines], axis=-1)
    return pos_encoding

def add_positional_encoding(inputs, max_len, d_model):
    pos_encoding = positional_encoding(max_len, d_model)
    pos_encoding = tf.cast(pos_encoding, dtype=tf.float32)
    
    pos_encoded_inputs = layers.Lambda(
        lambda x: x + pos_encoding[:tf.shape(x)[1], :]
    )(inputs)
    return pos_encoded_inputs

# 3. Transformer 블록 구현
class TransformerBlock(layers.Layer):
    def __init__(self, d_model, num_heads, ff_dim, rate=0.3):
        super(TransformerBlock, self).__init__()
        self.att1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.att2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.ffn = tf.keras.Sequential(
            [layers.Dense(ff_dim, activation="gelu"), layers.Dense(d_model)]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
        self.dropout3 = layers.Dropout(rate)

    def call(self, inputs):
        attn_output1 = self.att1(inputs, inputs)
        attn_output1 = self.dropout1(attn_output1)
        out1 = self.layernorm1(inputs + attn_output1)
        # attn_output2 = self.att2(out1, out1)
        # attn_output2 = self.dropout2(attn_output2)
        # out2 = self.layernorm1(out1 + attn_output2)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout1(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# 4. Transformer 모델 구성
def create_transformer_model(input_shape, num_heads, ff_dim, d_model, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # 임베딩 및 위치 인코딩
    embedding_layer = layers.Dense(d_model)(inputs)
    pos_encoded_inputs = add_positional_encoding(embedding_layer, max_len=input_shape[0], d_model=d_model)

    # Transformer 블록 적용
    transformer_block = TransformerBlock(d_model, num_heads, ff_dim)
    x = transformer_block(pos_encoded_inputs)
    
    # 출력 레이어
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation="gelu")(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# 5. 모델 생성 및 학습
input_shape = (10, 2)  # 10분 동안의 데이터 (2개의 피처: Close, Volume)
model = create_transformer_model(input_shape, num_heads=2, ff_dim=64, d_model=16, num_classes=3)

# 모델 컴파일
model.compile(optimizer=tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# 얼리스탑 콜백
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=100,
    verbose=1,
    restore_best_weights=True
)

# 모델 학습
history = model.fit(X_train, y_train, epochs=1000, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 10, 2)]           0
#
#  dense_65 (Dense)            (None, 10, 16)            48
#
#  lambda_13 (Lambda)          (None, 10, 16)            0
#
#  transformer_block_13 (Trans  (None, 10, 16)           4352
#  formerBlock)
#
#  global_average_pooling1d_11  (None, 16)               0
#   (GlobalAveragePooling1D)
#
#  dense_68 (Dense)            (None, 128)               2176
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  dense_69 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 6,963
# Trainable params: 6,963
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1168/1168 [==============================] - 19s 15ms/step - loss: 1.0744 - accuracy: 0.4143 - val_loss: 1.0447 - val_accuracy: 0.4239
# Epoch 2/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0442 - accuracy: 0.4241 - val_loss: 1.0480 - val_accuracy: 0.4145
# Epoch 3/1000
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0404 - accuracy: 0.4273 - val_loss: 1.0367 - val_accuracy: 0.4335
# Epoch 4/1000
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0393 - accuracy: 0.4292 - val_loss: 1.0368 - val_accuracy: 0.4314
# Epoch 5/1000
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0392 - accuracy: 0.4281 - val_loss: 1.0383 - val_accuracy: 0.4312
# Epoch 6/1000
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0389 - accuracy: 0.4301 - val_loss: 1.0364 - val_accuracy: 0.4339
# Epoch 7/1000
# 1168/1168 [==============================] - 18s 15ms/step - loss: 1.0384 - accuracy: 0.4311 - val_loss: 1.0381 - val_accuracy: 0.4288
# Epoch 8/1000
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0382 - accuracy: 0.4308 - val_loss: 1.0374 - val_accuracy: 0.4338
# Epoch 9/1000
# 1168/1168 [==============================] - 18s 16ms/step - loss: 1.0381 - accuracy: 0.4287 - val_loss: 1.0377 - val_accuracy: 0.4292
# Epoch 10/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0380 - accuracy: 0.4310 - val_loss: 1.0362 - val_accuracy: 0.4316
# Epoch 11/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0379 - accuracy: 0.4291 - val_loss: 1.0358 - val_accuracy: 0.4352
# Epoch 12/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0378 - accuracy: 0.4304 - val_loss: 1.0401 - val_accuracy: 0.4325
# Epoch 13/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4309 - val_loss: 1.0370 - val_accuracy: 0.4335
# Epoch 14/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0382 - accuracy: 0.4307 - val_loss: 1.0362 - val_accuracy: 0.4319
# Epoch 15/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0380 - accuracy: 0.4303 - val_loss: 1.0349 - val_accuracy: 0.4352
# Epoch 16/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0380 - accuracy: 0.4315 - val_loss: 1.0348 - val_accuracy: 0.4349
# Epoch 17/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4304 - val_loss: 1.0387 - val_accuracy: 0.4327
# Epoch 18/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0378 - accuracy: 0.4308 - val_loss: 1.0348 - val_accuracy: 0.4348
# Epoch 19/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0383 - accuracy: 0.4310 - val_loss: 1.0366 - val_accuracy: 0.4292
# Epoch 20/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0378 - accuracy: 0.4303 - val_loss: 1.0363 - val_accuracy: 0.4348
# Epoch 21/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0382 - accuracy: 0.4309 - val_loss: 1.0350 - val_accuracy: 0.4328
# Epoch 22/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0378 - accuracy: 0.4303 - val_loss: 1.0370 - val_accuracy: 0.4312
# Epoch 23/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0379 - accuracy: 0.4297 - val_loss: 1.0394 - val_accuracy: 0.4286
# Epoch 24/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0379 - accuracy: 0.4316 - val_loss: 1.0349 - val_accuracy: 0.4328
# Epoch 25/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4320 - val_loss: 1.0399 - val_accuracy: 0.4281
# Epoch 26/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0380 - accuracy: 0.4307 - val_loss: 1.0404 - val_accuracy: 0.4208
# Epoch 27/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4306 - val_loss: 1.0395 - val_accuracy: 0.4316
# Epoch 28/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4324 - val_loss: 1.0351 - val_accuracy: 0.4334
# Epoch 29/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0374 - accuracy: 0.4317 - val_loss: 1.0366 - val_accuracy: 0.4326
# Epoch 30/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0375 - accuracy: 0.4315 - val_loss: 1.0354 - val_accuracy: 0.4305
# Epoch 31/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4294 - val_loss: 1.0347 - val_accuracy: 0.4338
# Epoch 32/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0378 - accuracy: 0.4314 - val_loss: 1.0354 - val_accuracy: 0.4339
# Epoch 33/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4306 - val_loss: 1.0366 - val_accuracy: 0.4304
# Epoch 34/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0379 - accuracy: 0.4311 - val_loss: 1.0363 - val_accuracy: 0.4316
# Epoch 35/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0377 - accuracy: 0.4301 - val_loss: 1.0362 - val_accuracy: 0.4323
# Epoch 36/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0373 - accuracy: 0.4309 - val_loss: 1.0347 - val_accuracy: 0.4359
# Epoch 37/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0376 - accuracy: 0.4316 - val_loss: 1.0371 - val_accuracy: 0.4309
# Epoch 38/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0375 - accuracy: 0.4311 - val_loss: 1.0350 - val_accuracy: 0.4356
# Epoch 39/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0375 - accuracy: 0.4316 - val_loss: 1.0352 - val_accuracy: 0.4316
# Epoch 40/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0373 - accuracy: 0.4309 - val_loss: 1.0383 - val_accuracy: 0.4346
# Epoch 41/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0374 - accuracy: 0.4305 - val_loss: 1.0407 - val_accuracy: 0.4255
# Epoch 42/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0372 - accuracy: 0.4316 - val_loss: 1.0354 - val_accuracy: 0.4334
# Epoch 43/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4306 - val_loss: 1.0385 - val_accuracy: 0.4334
# Epoch 44/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0373 - accuracy: 0.4307 - val_loss: 1.0369 - val_accuracy: 0.4311
# Epoch 45/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0371 - accuracy: 0.4317 - val_loss: 1.0365 - val_accuracy: 0.4266
# Epoch 46/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4328 - val_loss: 1.0339 - val_accuracy: 0.4359
# Epoch 47/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0371 - accuracy: 0.4327 - val_loss: 1.0355 - val_accuracy: 0.4342
# Epoch 48/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4320 - val_loss: 1.0366 - val_accuracy: 0.4272
# Epoch 49/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4324 - val_loss: 1.0381 - val_accuracy: 0.4307
# Epoch 50/1000
# 1168/1168 [==============================] - 19s 17ms/step - loss: 1.0368 - accuracy: 0.4320 - val_loss: 1.0363 - val_accuracy: 0.4347
# Epoch 51/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0371 - accuracy: 0.4318 - val_loss: 1.0359 - val_accuracy: 0.4356
# Epoch 52/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4318 - val_loss: 1.0414 - val_accuracy: 0.4284
# Epoch 53/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4328 - val_loss: 1.0404 - val_accuracy: 0.4317
# Epoch 54/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4317 - val_loss: 1.0345 - val_accuracy: 0.4334
# Epoch 55/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4320 - val_loss: 1.0354 - val_accuracy: 0.4298
# Epoch 56/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4330 - val_loss: 1.0380 - val_accuracy: 0.4253
# Epoch 57/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4324 - val_loss: 1.0353 - val_accuracy: 0.4386
# Epoch 58/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4329 - val_loss: 1.0373 - val_accuracy: 0.4283
# Epoch 59/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4324 - val_loss: 1.0417 - val_accuracy: 0.4243
# Epoch 60/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4308 - val_loss: 1.0345 - val_accuracy: 0.4321
# Epoch 61/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4307 - val_loss: 1.0346 - val_accuracy: 0.4328
# Epoch 62/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4321 - val_loss: 1.0350 - val_accuracy: 0.4344
# Epoch 63/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4317 - val_loss: 1.0366 - val_accuracy: 0.4257
# Epoch 64/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4325 - val_loss: 1.0404 - val_accuracy: 0.4344
# Epoch 65/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4310 - val_loss: 1.0350 - val_accuracy: 0.4360
# Epoch 66/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4327 - val_loss: 1.0364 - val_accuracy: 0.4342
# Epoch 67/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4315 - val_loss: 1.0358 - val_accuracy: 0.4365
# Epoch 68/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4321 - val_loss: 1.0365 - val_accuracy: 0.4300
# Epoch 69/1000
# 1168/1168 [==============================] - 19s 17ms/step - loss: 1.0368 - accuracy: 0.4315 - val_loss: 1.0363 - val_accuracy: 0.4340
# Epoch 70/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4311 - val_loss: 1.0385 - val_accuracy: 0.4239
# Epoch 71/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4324 - val_loss: 1.0347 - val_accuracy: 0.4387
# Epoch 72/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4334 - val_loss: 1.0360 - val_accuracy: 0.4328
# Epoch 73/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4333 - val_loss: 1.0353 - val_accuracy: 0.4382
# Epoch 74/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4331 - val_loss: 1.0349 - val_accuracy: 0.4346
# Epoch 75/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4318 - val_loss: 1.0359 - val_accuracy: 0.4345
# Epoch 76/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4330 - val_loss: 1.0357 - val_accuracy: 0.4347
# Epoch 77/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4322 - val_loss: 1.0358 - val_accuracy: 0.4377
# Epoch 78/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4321 - val_loss: 1.0341 - val_accuracy: 0.4380
# Epoch 79/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4327 - val_loss: 1.0344 - val_accuracy: 0.4350
# Epoch 80/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4334 - val_loss: 1.0393 - val_accuracy: 0.4287
# Epoch 81/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4323 - val_loss: 1.0361 - val_accuracy: 0.4291
# Epoch 82/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4324 - val_loss: 1.0368 - val_accuracy: 0.4348
# Epoch 83/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4334 - val_loss: 1.0368 - val_accuracy: 0.4356
# Epoch 84/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4321 - val_loss: 1.0369 - val_accuracy: 0.4306
# Epoch 85/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0362 - accuracy: 0.4345 - val_loss: 1.0382 - val_accuracy: 0.4342
# Epoch 86/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4331 - val_loss: 1.0357 - val_accuracy: 0.4305
# Epoch 87/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4326 - val_loss: 1.0357 - val_accuracy: 0.4327
# Epoch 88/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4334 - val_loss: 1.0340 - val_accuracy: 0.4373
# Epoch 89/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4327 - val_loss: 1.0347 - val_accuracy: 0.4348
# Epoch 90/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4336 - val_loss: 1.0341 - val_accuracy: 0.4364
# Epoch 91/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4342 - val_loss: 1.0391 - val_accuracy: 0.4322
# Epoch 92/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4316 - val_loss: 1.0356 - val_accuracy: 0.4314
# Epoch 93/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4316 - val_loss: 1.0337 - val_accuracy: 0.4363
# Epoch 94/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4324 - val_loss: 1.0378 - val_accuracy: 0.4353
# Epoch 95/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4324 - val_loss: 1.0359 - val_accuracy: 0.4299
# Epoch 96/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4337 - val_loss: 1.0370 - val_accuracy: 0.4361
# Epoch 97/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4315 - val_loss: 1.0406 - val_accuracy: 0.4287
# Epoch 98/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4322 - val_loss: 1.0349 - val_accuracy: 0.4355
# Epoch 99/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4323 - val_loss: 1.0330 - val_accuracy: 0.4378
# Epoch 100/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4328 - val_loss: 1.0429 - val_accuracy: 0.4343
# Epoch 101/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4335 - val_loss: 1.0362 - val_accuracy: 0.4278
# Epoch 102/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4319 - val_loss: 1.0436 - val_accuracy: 0.4191
# Epoch 103/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4326 - val_loss: 1.0360 - val_accuracy: 0.4291
# Epoch 104/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4324 - val_loss: 1.0352 - val_accuracy: 0.4380
# Epoch 105/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4330 - val_loss: 1.0413 - val_accuracy: 0.4249
# Epoch 106/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4326 - val_loss: 1.0360 - val_accuracy: 0.4318
# Epoch 107/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4321 - val_loss: 1.0360 - val_accuracy: 0.4335
# Epoch 108/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4322 - val_loss: 1.0424 - val_accuracy: 0.4257
# Epoch 109/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0372 - accuracy: 0.4319 - val_loss: 1.0376 - val_accuracy: 0.4340
# Epoch 110/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4330 - val_loss: 1.0353 - val_accuracy: 0.4373
# Epoch 111/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4334 - val_loss: 1.0348 - val_accuracy: 0.4338
# Epoch 112/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4324 - val_loss: 1.0360 - val_accuracy: 0.4364
# Epoch 113/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4332 - val_loss: 1.0388 - val_accuracy: 0.4364
# Epoch 114/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0362 - accuracy: 0.4322 - val_loss: 1.0340 - val_accuracy: 0.4359
# Epoch 115/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4344 - val_loss: 1.0352 - val_accuracy: 0.4341
# Epoch 116/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4327 - val_loss: 1.0400 - val_accuracy: 0.4317
# Epoch 117/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4332 - val_loss: 1.0361 - val_accuracy: 0.4335
# Epoch 118/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4322 - val_loss: 1.0351 - val_accuracy: 0.4323
# Epoch 119/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4320 - val_loss: 1.0350 - val_accuracy: 0.4382
# Epoch 120/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4324 - val_loss: 1.0352 - val_accuracy: 0.4359
# Epoch 121/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4325 - val_loss: 1.0340 - val_accuracy: 0.4382
# Epoch 122/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4322 - val_loss: 1.0340 - val_accuracy: 0.4376
# Epoch 123/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4327 - val_loss: 1.0365 - val_accuracy: 0.4356
# Epoch 124/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4326 - val_loss: 1.0377 - val_accuracy: 0.4294
# Epoch 125/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4327 - val_loss: 1.0356 - val_accuracy: 0.4318
# Epoch 126/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0362 - accuracy: 0.4328 - val_loss: 1.0361 - val_accuracy: 0.4309
# Epoch 127/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4331 - val_loss: 1.0378 - val_accuracy: 0.4246
# Epoch 128/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4318 - val_loss: 1.0350 - val_accuracy: 0.4354
# Epoch 129/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4329 - val_loss: 1.0345 - val_accuracy: 0.4368
# Epoch 130/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4331 - val_loss: 1.0359 - val_accuracy: 0.4307
# Epoch 131/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4315 - val_loss: 1.0383 - val_accuracy: 0.4357
# Epoch 132/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4331 - val_loss: 1.0347 - val_accuracy: 0.4359
# Epoch 133/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4338 - val_loss: 1.0334 - val_accuracy: 0.4378
# Epoch 134/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4330 - val_loss: 1.0342 - val_accuracy: 0.4361
# Epoch 135/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4336 - val_loss: 1.0395 - val_accuracy: 0.4288
# Epoch 136/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4325 - val_loss: 1.0371 - val_accuracy: 0.4334
# Epoch 137/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4321 - val_loss: 1.0413 - val_accuracy: 0.4302
# Epoch 138/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4331 - val_loss: 1.0376 - val_accuracy: 0.4279
# Epoch 139/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4331 - val_loss: 1.0340 - val_accuracy: 0.4355
# Epoch 140/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4325 - val_loss: 1.0363 - val_accuracy: 0.4369
# Epoch 141/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4308 - val_loss: 1.0340 - val_accuracy: 0.4356
# Epoch 142/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4321 - val_loss: 1.0345 - val_accuracy: 0.4348
# Epoch 143/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4317 - val_loss: 1.0387 - val_accuracy: 0.4350
# Epoch 144/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4331 - val_loss: 1.0368 - val_accuracy: 0.4334
# Epoch 145/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4341 - val_loss: 1.0373 - val_accuracy: 0.4318
# Epoch 146/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4316 - val_loss: 1.0360 - val_accuracy: 0.4320
# Epoch 147/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4317 - val_loss: 1.0371 - val_accuracy: 0.4323
# Epoch 148/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0372 - accuracy: 0.4326 - val_loss: 1.0345 - val_accuracy: 0.4341
# Epoch 149/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4324 - val_loss: 1.0351 - val_accuracy: 0.4363
# Epoch 150/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4321 - val_loss: 1.0374 - val_accuracy: 0.4350
# Epoch 151/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4331 - val_loss: 1.0349 - val_accuracy: 0.4314
# Epoch 152/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0371 - accuracy: 0.4328 - val_loss: 1.0396 - val_accuracy: 0.4340
# Epoch 153/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4328 - val_loss: 1.0383 - val_accuracy: 0.4363
# Epoch 154/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4323 - val_loss: 1.0347 - val_accuracy: 0.4353
# Epoch 155/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4328 - val_loss: 1.0360 - val_accuracy: 0.4333
# Epoch 156/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4323 - val_loss: 1.0400 - val_accuracy: 0.4324
# Epoch 157/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4319 - val_loss: 1.0370 - val_accuracy: 0.4314
# Epoch 158/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4336 - val_loss: 1.0346 - val_accuracy: 0.4351
# Epoch 159/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4333 - val_loss: 1.0425 - val_accuracy: 0.4283
# Epoch 160/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4325 - val_loss: 1.0362 - val_accuracy: 0.4351
# Epoch 161/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4329 - val_loss: 1.0333 - val_accuracy: 0.4366
# Epoch 162/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4329 - val_loss: 1.0363 - val_accuracy: 0.4295
# Epoch 163/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4325 - val_loss: 1.0341 - val_accuracy: 0.4354
# Epoch 164/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4327 - val_loss: 1.0381 - val_accuracy: 0.4330
# Epoch 165/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4330 - val_loss: 1.0336 - val_accuracy: 0.4379
# Epoch 166/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4326 - val_loss: 1.0388 - val_accuracy: 0.4339
# Epoch 167/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4320 - val_loss: 1.0356 - val_accuracy: 0.4320
# Epoch 168/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4344 - val_loss: 1.0369 - val_accuracy: 0.4338
# Epoch 169/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4331 - val_loss: 1.0394 - val_accuracy: 0.4295
# Epoch 170/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4328 - val_loss: 1.0354 - val_accuracy: 0.4344
# Epoch 171/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4336 - val_loss: 1.0358 - val_accuracy: 0.4373
# Epoch 172/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4325 - val_loss: 1.0372 - val_accuracy: 0.4281
# Epoch 173/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4335 - val_loss: 1.0340 - val_accuracy: 0.4385
# Epoch 174/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4311 - val_loss: 1.0346 - val_accuracy: 0.4359
# Epoch 175/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4328 - val_loss: 1.0348 - val_accuracy: 0.4362
# Epoch 176/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4327 - val_loss: 1.0374 - val_accuracy: 0.4325
# Epoch 177/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4332 - val_loss: 1.0348 - val_accuracy: 0.4342
# Epoch 178/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4320 - val_loss: 1.0350 - val_accuracy: 0.4364
# Epoch 179/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0371 - accuracy: 0.4332 - val_loss: 1.0365 - val_accuracy: 0.4355
# Epoch 180/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4311 - val_loss: 1.0359 - val_accuracy: 0.4326
# Epoch 181/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4325 - val_loss: 1.0367 - val_accuracy: 0.4296
# Epoch 182/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4323 - val_loss: 1.0338 - val_accuracy: 0.4377
# Epoch 183/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0362 - accuracy: 0.4331 - val_loss: 1.0380 - val_accuracy: 0.4242
# Epoch 184/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4331 - val_loss: 1.0346 - val_accuracy: 0.4344
# Epoch 185/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0369 - accuracy: 0.4317 - val_loss: 1.0344 - val_accuracy: 0.4347
# Epoch 186/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4323 - val_loss: 1.0347 - val_accuracy: 0.4356
# Epoch 187/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4327 - val_loss: 1.0339 - val_accuracy: 0.4347
# Epoch 188/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4322 - val_loss: 1.0353 - val_accuracy: 0.4315
# Epoch 189/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0368 - accuracy: 0.4327 - val_loss: 1.0380 - val_accuracy: 0.4319
# Epoch 190/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0365 - accuracy: 0.4325 - val_loss: 1.0372 - val_accuracy: 0.4303
# Epoch 191/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4321 - val_loss: 1.0356 - val_accuracy: 0.4350
# Epoch 192/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4328 - val_loss: 1.0350 - val_accuracy: 0.4339
# Epoch 193/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0372 - accuracy: 0.4313 - val_loss: 1.0379 - val_accuracy: 0.4324
# Epoch 194/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0367 - accuracy: 0.4317 - val_loss: 1.0345 - val_accuracy: 0.4380
# Epoch 195/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0364 - accuracy: 0.4331 - val_loss: 1.0342 - val_accuracy: 0.4373
# Epoch 196/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4318 - val_loss: 1.0346 - val_accuracy: 0.4356
# Epoch 197/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0366 - accuracy: 0.4330 - val_loss: 1.0356 - val_accuracy: 0.4336
# Epoch 198/1000
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0363 - accuracy: 0.4337 - val_loss: 1.0387 - val_accuracy: 0.4320
# Epoch 199/1000
# 1168/1168 [==============================] - ETA: 0s - loss: 1.0370 - accuracy: 0.4330Restoring model weights from the end of the best epoch: 99.
# 1168/1168 [==============================] - 19s 16ms/step - loss: 1.0370 - accuracy: 0.4330 - val_loss: 1.0343 - val_accuracy: 0.4373
# Epoch 199: early stopping

# %%
import matplotlib.pyplot as plt

# 손실 시각화
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 시각화
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import matplotlib.pyplot as plt
#       3 # 손실 시각화
# ----> 4 plt.plot(history.history['loss'], label='Train Loss')
#       5 plt.plot(history.history['val_loss'], label='Validation Loss')
#       6 plt.title('Loss')
#
# NameError: name 'history' is not defined
